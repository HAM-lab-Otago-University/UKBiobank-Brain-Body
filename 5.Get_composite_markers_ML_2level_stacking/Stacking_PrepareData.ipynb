# %%
import csv
import os
import random
import pickle
import gc
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import sklearn
import warnings
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

# %%
def analyze_g_matched(fold, paths):
    """Analyze g-matched files for a given fold"""
    # Load files
    train = pd.read_csv(paths['stacking_output']['train_g_matched_inner'].format(fold)).drop(columns=['eid', 'g'])
    test = pd.read_csv(paths['stacking_output']['test_g_matched_inner'].format(fold)).drop(columns=['eid', 'g'])
    
    train_out = pd.read_csv(paths['stacking_output']['train_g_matched_outer'].format(fold))
    test_out = pd.read_csv(paths['stacking_output']['test_g_matched_outer'].format(fold))
    # Calculate metrics
    metrics = {
        'Fold': fold,
        'N Train Inner': len(train),
        'N Test Inner': len(test),
        'N Train Outer': len(train_out),
        'N Test Outer': len(test_out),
        'N Features': train.shape[1],
        'ncols Train': list(train.columns),
        'ncols Test': list(test.columns)
    }
    return metrics

# %% [markdown]
# # Prepare data

# %%
# Config
base_path = '/UK_BB/brainbody'
folds = range(0, 5)

# %% [markdown]
# ## Brain

# %%
# Define modalities
modalities_smri = [
'struct_fast',
'struct_sub_first',
'struct_fs_aseg_mean_intensity',
'struct_fs_aseg_volume',
'struct_ba_exvivo_area', 
'struct_ba_exvivo_mean_thickness',
'struct_ba_exvivo_volume',
'struct_a2009s_area',
'struct_a2009s_mean_thickness',
'struct_a2009s_volume',
'struct_dkt_area',
'struct_dkt_mean_thickness',
'struct_dkt_volume',
'struct_desikan_gw',
'struct_desikan_pial',
'struct_desikan_white_area',
'struct_desikan_white_mean_thickness',
'struct_desikan_white_volume',
'struct_subsegmentation',
'add_t1',
'add_t2'
]
print('smri:', len(modalities_smri))
modalities_dwi = [
"dwi_FA_tbss", "dwi_FA_prob",
"dwi_MD_tbss", "dwi_MD_prob",
"dwi_L1_tbss", "dwi_L1_prob",
"dwi_L2_tbss", "dwi_L2_prob",
"dwi_L3_tbss", "dwi_L3_prob",
"dwi_MO_tbss", "dwi_MO_prob",
"dwi_OD_tbss", "dwi_OD_prob",
"dwi_ICVF_tbss", "dwi_ICVF_prob",
"dwi_ISOVF_tbss", "dwi_ISOVF_prob",

'aparc_Tian_S1_FA_i2',
'aparc_Tian_S1_Length_i2',
'aparc_Tian_S1_SIFT2_FBC_i2',
'aparc_Tian_S1_Streamline_Count_i2',

'aparc_a2009s_Tian_S1_FA_i2',
'aparc_a2009s_Tian_S1_Length_i2',
'aparc_a2009s_Tian_S1_SIFT2_FBC_i2',
'aparc_a2009s_Tian_S1_Streamline_Count_i2',

'Glasser_Tian_S1_FA_i2',
'Glasser_Tian_S1_Length_i2',
'Glasser_Tian_S1_SIFT2_FBC_i2',
'Glasser_Tian_S1_Streamline_Count_i2',

'Glasser_Tian_S4_FA_i2',
'Glasser_Tian_S4_Length_i2',
'Glasser_Tian_S4_SIFT2_FBC_i2',
'Glasser_Tian_S4_Streamline_Count_i2',

'Schaefer7n200p_Tian_S1_FA_i2',
'Schaefer7n200p_Tian_S1_Length_i2',
'Schaefer7n200p_Tian_S1_SIFT2_FBC_i2',
'Schaefer7n200p_Tian_S1_Streamline_Count_i2',

'Schaefer7n1000p_Tian_S4_FA_i2',
'Schaefer7n1000p_Tian_S4_Length_i2',
'Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2',
'Schaefer7n1000p_Tian_S4_Streamline_Count_i2']

print('dwi:', len(modalities_dwi))

modalities_rs = [
"amplitudes_21",
"full_correlation_21",
"partial_correlation_21",
"amplitudes_55",
"full_correlation_55",
"partial_correlation_55",
'full_correlation_aparc_a2009s_Tian_S1',
'full_correlation_aparc_Tian_S1',
'full_correlation_Glasser_Tian_S1',
'full_correlation_Glasser_Tian_S4',
'full_correlation_Schaefer7n200p_Tian_S1',
'full_correlation_Schaefer7n500p_Tian_S4',
'partial_correlation_aparc_a2009s_Tian_S1',
'partial_correlation_aparc_Tian_S1',
'partial_correlation_Glasser_Tian_S1',
'partial_correlation_Glasser_Tian_S4',
'partial_correlation_Schaefer7n200p_Tian_S1',
'partial_correlation_Schaefer7n500p_Tian_S4'
]


print('rs:', len(modalities_rs))

modalities_mri = [
'struct_fast',
'struct_sub_first',
'struct_fs_aseg_mean_intensity',
'struct_fs_aseg_volume',
'struct_ba_exvivo_area', 
'struct_ba_exvivo_mean_thickness',
'struct_ba_exvivo_volume',
'struct_a2009s_area',
'struct_a2009s_mean_thickness',
'struct_a2009s_volume',
'struct_dkt_area',
'struct_dkt_mean_thickness',
'struct_dkt_volume',
'struct_desikan_gw',
'struct_desikan_pial',
'struct_desikan_white_area',
'struct_desikan_white_mean_thickness',
'struct_desikan_white_volume',
'struct_subsegmentation',
'add_t1',
'add_t2',

"dwi_FA_tbss", "dwi_FA_prob",
"dwi_MD_tbss", "dwi_MD_prob",
"dwi_L1_tbss", "dwi_L1_prob",
"dwi_L2_tbss", "dwi_L2_prob",
"dwi_L3_tbss", "dwi_L3_prob",
"dwi_MO_tbss", "dwi_MO_prob",
"dwi_OD_tbss", "dwi_OD_prob",
"dwi_ICVF_tbss", "dwi_ICVF_prob",
"dwi_ISOVF_tbss", "dwi_ISOVF_prob",

'aparc_Tian_S1_FA_i2',
'aparc_Tian_S1_Length_i2',
'aparc_Tian_S1_SIFT2_FBC_i2',
'aparc_Tian_S1_Streamline_Count_i2',

'aparc_a2009s_Tian_S1_FA_i2',
'aparc_a2009s_Tian_S1_Length_i2',
'aparc_a2009s_Tian_S1_SIFT2_FBC_i2',
'aparc_a2009s_Tian_S1_Streamline_Count_i2',

'Glasser_Tian_S1_FA_i2',
'Glasser_Tian_S1_Length_i2',
'Glasser_Tian_S1_SIFT2_FBC_i2',
'Glasser_Tian_S1_Streamline_Count_i2',

'Glasser_Tian_S4_FA_i2',
'Glasser_Tian_S4_Length_i2',
'Glasser_Tian_S4_SIFT2_FBC_i2',
'Glasser_Tian_S4_Streamline_Count_i2',

'Schaefer7n200p_Tian_S1_FA_i2',
'Schaefer7n200p_Tian_S1_Length_i2',
'Schaefer7n200p_Tian_S1_SIFT2_FBC_i2',
'Schaefer7n200p_Tian_S1_Streamline_Count_i2',

'Schaefer7n1000p_Tian_S4_FA_i2',
'Schaefer7n1000p_Tian_S4_Length_i2',
'Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2',
'Schaefer7n1000p_Tian_S4_Streamline_Count_i2',

"amplitudes_21",
"full_correlation_21",
"partial_correlation_21",
"amplitudes_55",
"full_correlation_55",
"partial_correlation_55",
'full_correlation_aparc_a2009s_Tian_S1',
'full_correlation_aparc_Tian_S1',
'full_correlation_Glasser_Tian_S1',
'full_correlation_Glasser_Tian_S4',
'full_correlation_Schaefer7n200p_Tian_S1',
'full_correlation_Schaefer7n500p_Tian_S4',
'partial_correlation_aparc_a2009s_Tian_S1',
'partial_correlation_aparc_Tian_S1',
'partial_correlation_Glasser_Tian_S1',
'partial_correlation_Glasser_Tian_S4',
'partial_correlation_Schaefer7n200p_Tian_S1',
'partial_correlation_Schaefer7n500p_Tian_S4'

]

print('all mri:', len(modalities_mri))
# Out:
# smri: 21
# dwi: 42
# rs: 18
# all mri: 81

# %% [markdown]
# ### sMRI

# %%
# Match features and targets
base_path = '/UK_BB/brainbody'
paths = {
    'g_pred': {
        'train': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
        'test': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
    },
    'g_observed': {
        'train': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_train_with_id_{}.csv'),
        'test': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_test_with_id_{}.csv')
    },
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'smri','features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'smri','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'smri','features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'smri','features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'smri','features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'smri','features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'smri','features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}

for path_key in paths['stacking_output']:
    os.makedirs(os.path.dirname(paths['stacking_output'][path_key].format(0)), exist_ok=True)
    
# Match features and targets
folds = range(0, 5)
warnings.simplefilter(action='ignore', category=FutureWarning)

for fold in folds:
    print(f'Started {fold}', flush=True)
    all_modalities_train = []
    all_modalities_test = []
    
    for modality in modalities_smri:
        # Read train and test predictions using formatted paths
        train_path = paths['g_pred']['train'].format(fold, modality, fold)
        test_path = paths['g_pred']['test'].format(fold, modality, fold)
        
        g_train_pred_level1 = pd.read_csv(train_path)
        g_test_pred_level1 = pd.read_csv(test_path)
        
        print(f'g TRAIN shape BEFORE stacking ({modality}):', g_train_pred_level1.shape)
        print(f'g TEST shape BEFORE stacking ({modality}):', g_test_pred_level1.shape)
        
        all_modalities_train.append(g_train_pred_level1)
        all_modalities_test.append(g_test_pred_level1)
    
    # Initialize with first modality
    features_train_level1_inner = all_modalities_train[0]
    features_train_level1_outer = all_modalities_train[0]
    features_test_level1_inner = all_modalities_test[0]
    features_test_level1_outer = all_modalities_test[0]
    
    # Stack train data with both merge types
    for i in range(1, len(all_modalities_train)):
        features_train_level1_inner = pd.merge(features_train_level1_inner, all_modalities_train[i], on='eid', how='inner')
        features_train_level1_outer = pd.merge(features_train_level1_outer, all_modalities_train[i], on='eid', how='outer')
    
    # Save stacked train data
    features_train_level1_inner.to_csv(paths['stacking_output']['train_stacked_inner'].format(fold), index=False)
    features_train_level1_outer.to_csv(paths['stacking_output']['train_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_train = pd.read_csv(paths['g_observed']['train'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_train_level1_inner_g_matched = pd.merge(features_train_level1_inner, g_observed_train, on='eid', how='inner')
    features_train_level1_inner_g_matched.to_csv(paths['stacking_output']['train_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_train_level1_outer_g_matched = pd.merge(features_train_level1_outer, g_observed_train, on='eid', how='left')
    features_train_level1_outer_g_matched.to_csv(paths['stacking_output']['train_g_matched_outer'].format(fold), index=False)
    
    print('g TRAIN shape AFTER inner stacking:', features_train_level1_inner_g_matched.shape)
    print('g TRAIN shape AFTER outer stacking:', features_train_level1_outer_g_matched.shape)
    
    # Stack test data with both merge types
    for i in range(1, len(all_modalities_test)):
        features_test_level1_inner = pd.merge(features_test_level1_inner, all_modalities_test[i], on='eid', how='inner')
        features_test_level1_outer = pd.merge(features_test_level1_outer, all_modalities_test[i], on='eid', how='outer')
    
    # Save stacked test data
    features_test_level1_inner.to_csv(paths['stacking_output']['test_stacked_inner'].format(fold), index=False)
    features_test_level1_outer.to_csv(paths['stacking_output']['test_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_test = pd.read_csv(paths['g_observed']['test'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_test_level1_inner_g_matched = pd.merge(features_test_level1_inner, g_observed_test, on='eid', how='inner')
    features_test_level1_inner_g_matched.to_csv(paths['stacking_output']['test_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_test_level1_outer_g_matched = pd.merge(features_test_level1_outer, g_observed_test, on='eid', how='left')
    features_test_level1_outer_g_matched.to_csv(paths['stacking_output']['test_g_matched_outer'].format(fold), index=False)
    
    print('g TEST shape AFTER inner stacking:', features_test_level1_inner_g_matched.shape)
    print('g TEST shape AFTER outer stacking:', features_test_level1_outer_g_matched.shape)
# Out:
# Started 0
# g TRAIN shape BEFORE stacking (struct_fast): (21977, 2)
# g TEST shape BEFORE stacking (struct_fast): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21977, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21977, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21977, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21977, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21950, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5467, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21950, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5467, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21950, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5467, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21977, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21977, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21977, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5474, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21977, 2)
# g TEST shape BEFORE stacking (add_t1): (5474, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21737, 2)
# g TEST shape BEFORE stacking (add_t2): (5422, 2)
# g TRAIN shape AFTER inner stacking: (21710, 23)
# g TRAIN shape AFTER outer stacking: (21977, 23)
# g TEST shape AFTER inner stacking: (5415, 23)
# g TEST shape AFTER outer stacking: (5474, 23)
# Started 1
# g TRAIN shape BEFORE stacking (struct_fast): (21920, 2)
# g TEST shape BEFORE stacking (struct_fast): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21920, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21920, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21920, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21920, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21896, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5521, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21896, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5521, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21896, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5521, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21920, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21920, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21920, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5531, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21920, 2)
# g TEST shape BEFORE stacking (add_t1): (5531, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21689, 2)
# g TEST shape BEFORE stacking (add_t2): (5470, 2)
# g TRAIN shape AFTER inner stacking: (21665, 23)
# g TRAIN shape AFTER outer stacking: (21920, 23)
# g TEST shape AFTER inner stacking: (5460, 23)
# g TEST shape AFTER outer stacking: (5531, 23)
# Started 2
# g TRAIN shape BEFORE stacking (struct_fast): (21965, 2)
# g TEST shape BEFORE stacking (struct_fast): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21965, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21965, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21965, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21965, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21937, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5480, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21937, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5480, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21937, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5480, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21965, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21965, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21965, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5486, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21965, 2)
# g TEST shape BEFORE stacking (add_t1): (5486, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21730, 2)
# g TEST shape BEFORE stacking (add_t2): (5429, 2)
# g TRAIN shape AFTER inner stacking: (21702, 23)
# g TRAIN shape AFTER outer stacking: (21965, 23)
# g TEST shape AFTER inner stacking: (5423, 23)
# g TEST shape AFTER outer stacking: (5486, 23)
# Started 3
# g TRAIN shape BEFORE stacking (struct_fast): (22031, 2)
# g TEST shape BEFORE stacking (struct_fast): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (22031, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (22031, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (22031, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (22031, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21999, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5418, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21999, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5418, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21999, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5418, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (22031, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (22031, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (22031, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5420, 2)
# g TRAIN shape BEFORE stacking (add_t1): (22031, 2)
# g TEST shape BEFORE stacking (add_t1): (5420, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21792, 2)
# g TEST shape BEFORE stacking (add_t2): (5367, 2)
# g TRAIN shape AFTER inner stacking: (21760, 23)
# g TRAIN shape AFTER outer stacking: (22031, 23)
# g TEST shape AFTER inner stacking: (5365, 23)
# g TEST shape AFTER outer stacking: (5420, 23)
# Started 4
# g TRAIN shape BEFORE stacking (struct_fast): (21911, 2)
# g TEST shape BEFORE stacking (struct_fast): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21911, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21911, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21911, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21911, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21886, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21886, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21886, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21911, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21911, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21911, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5540, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21911, 2)
# g TEST shape BEFORE stacking (add_t1): (5540, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21688, 2)
# g TEST shape BEFORE stacking (add_t2): (5471, 2)
# g TRAIN shape AFTER inner stacking: (21663, 23)
# g TRAIN shape AFTER outer stacking: (21911, 23)
# g TEST shape AFTER inner stacking: (5462, 23)
# g TEST shape AFTER outer stacking: (5540, 23)

# %%
# Analyze all folds
paths = {
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'smri',  'features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'smri', 'features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}

results = [analyze_g_matched(fold, paths) for fold in folds]
results_df = pd.DataFrame(results)
all_features_consistent = all(
    set(r['ncols Train']) == set(results[0]['ncols Train']) 
    for r in results)

print("Sample Sizes and Feature Counts:")
results_df[['Fold', 'N Train Inner', 'N Test Inner', 'N Train Outer', 'N Test Outer', 'N Features']]
# Out:
# Sample Sizes and Feature Counts:
#    Fold  N Train Inner  N Test Inner  N Train Outer  N Test Outer  N Features
# 0     0          21710          5415          21977          5474          21
# 1     1          21665          5460          21920          5531          21
# 2     2          21702          5423          21965          5486          21
# 3     3          21760          5365          22031          5420          21
# 4     4          21663          5462          21911          5540          21

# %% [markdown]
# ### dwMRI

# %%
# Match features and targets
base_path = '/UK_BB/brainbody'
paths = {
    'g_pred': {
        'train': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
        'test': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
    },
    'g_observed': {
        'train': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_train_with_id_{}.csv'),
        'test': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_test_with_id_{}.csv')
    },
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi','features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}

# Add this right after the paths dictionary definition (before the folds loop)
for path_key in paths['stacking_output']:
    os.makedirs(os.path.dirname(paths['stacking_output'][path_key].format(0)), exist_ok=True)
    
# Match features and targets
folds = range(0, 5)
warnings.simplefilter(action='ignore', category=FutureWarning)

for fold in folds:
    print(f'Started {fold}', flush=True)
    all_modalities_train = []
    all_modalities_test = []
    
    for modality in modalities_dwi:
        # Read train and test predictions using formatted paths
        train_path = paths['g_pred']['train'].format(fold, modality, fold)
        test_path = paths['g_pred']['test'].format(fold, modality, fold)
        
        g_train_pred_level1 = pd.read_csv(train_path)
        g_test_pred_level1 = pd.read_csv(test_path)
        
        print(f'g TRAIN shape BEFORE stacking ({modality}):', g_train_pred_level1.shape)
        print(f'g TEST shape BEFORE stacking ({modality}):', g_test_pred_level1.shape)
        
        all_modalities_train.append(g_train_pred_level1)
        all_modalities_test.append(g_test_pred_level1)
    
    # Initialize with first modality
    features_train_level1_inner = all_modalities_train[0]
    features_train_level1_outer = all_modalities_train[0]
    features_test_level1_inner = all_modalities_test[0]
    features_test_level1_outer = all_modalities_test[0]
    
    # Stack train data with both merge types
    for i in range(1, len(all_modalities_train)):
        features_train_level1_inner = pd.merge(features_train_level1_inner, all_modalities_train[i], on='eid', how='inner')
        features_train_level1_outer = pd.merge(features_train_level1_outer, all_modalities_train[i], on='eid', how='outer')
    
    # Save stacked train data
    features_train_level1_inner.to_csv(paths['stacking_output']['train_stacked_inner'].format(fold), index=False)
    features_train_level1_outer.to_csv(paths['stacking_output']['train_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_train = pd.read_csv(paths['g_observed']['train'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_train_level1_inner_g_matched = pd.merge(features_train_level1_inner, g_observed_train, on='eid', how='inner')
    features_train_level1_inner_g_matched.to_csv(paths['stacking_output']['train_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_train_level1_outer_g_matched = pd.merge(features_train_level1_outer, g_observed_train, on='eid', how='left')
    features_train_level1_outer_g_matched.to_csv(paths['stacking_output']['train_g_matched_outer'].format(fold), index=False)
    
    print('g TRAIN shape AFTER inner stacking:', features_train_level1_inner_g_matched.shape)
    print('g TRAIN shape AFTER outer stacking:', features_train_level1_outer_g_matched.shape)
    
    # Stack test data with both merge types
    for i in range(1, len(all_modalities_test)):
        features_test_level1_inner = pd.merge(features_test_level1_inner, all_modalities_test[i], on='eid', how='inner')
        features_test_level1_outer = pd.merge(features_test_level1_outer, all_modalities_test[i], on='eid', how='outer')
    
    # Save stacked test data
    features_test_level1_inner.to_csv(paths['stacking_output']['test_stacked_inner'].format(fold), index=False)
    features_test_level1_outer.to_csv(paths['stacking_output']['test_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_test = pd.read_csv(paths['g_observed']['test'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_test_level1_inner_g_matched = pd.merge(features_test_level1_inner, g_observed_test, on='eid', how='inner')
    features_test_level1_inner_g_matched.to_csv(paths['stacking_output']['test_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_test_level1_outer_g_matched = pd.merge(features_test_level1_outer, g_observed_test, on='eid', how='left')
    features_test_level1_outer_g_matched.to_csv(paths['stacking_output']['test_g_matched_outer'].format(fold), index=False)
    
    print('g TEST shape AFTER inner stacking:', features_test_level1_inner_g_matched.shape)
    print('g TEST shape AFTER outer stacking:', features_test_level1_outer_g_matched.shape)

# %%
# Analyze all folds
paths = {
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi',  'features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'dwi', 'features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}


results = [analyze_g_matched(fold, paths) for fold in folds]
results_df = pd.DataFrame(results)
all_features_consistent = all(
    set(r['ncols Train']) == set(results[0]['ncols Train']) 
    for r in results)

print("Sample Sizes and Feature Counts:")
results_df[['Fold', 'N Train Inner', 'N Test Inner', 'N Train Outer', 'N Test Outer', 'N Features']]
# Out:
# Sample Sizes and Feature Counts:
#    Fold  N Train Inner  N Test Inner  N Train Outer  N Test Outer  N Features
# 0     0          20646          5162          21555          5389          42
# 1     1          20601          5207          21518          5426          42
# 2     2          20647          5161          21556          5388          42
# 3     3          20738          5070          21626          5318          42
# 4     4          20600          5208          21521          5423          42

# %% [markdown]
# ### rsMRI

# %%
# Match features and targets
base_path = '/UK_BB/brainbody'
paths = {
    'g_pred': {
        'train': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
        'test': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
    },
    'g_observed': {
        'train': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_train_with_id_{}.csv'),
        'test': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_test_with_id_{}.csv')
    },
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'rs','features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'rs','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'rs','features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'rs','features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'rs','features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'rs','features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'rs','features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}

# Add this right after the paths dictionary definition (before the folds loop)
for path_key in paths['stacking_output']:
    os.makedirs(os.path.dirname(paths['stacking_output'][path_key].format(0)), exist_ok=True)
    
# Match features and targets
folds = range(0, 5)
warnings.simplefilter(action='ignore', category=FutureWarning)

for fold in folds:
    print(f'Started {fold}', flush=True)
    all_modalities_train = []
    all_modalities_test = []
    
    for modality in modalities_rs:
        # Read train and test predictions using formatted paths
        train_path = paths['g_pred']['train'].format(fold, modality, fold)
        test_path = paths['g_pred']['test'].format(fold, modality, fold)
        
        g_train_pred_level1 = pd.read_csv(train_path)
        g_test_pred_level1 = pd.read_csv(test_path)
        
        print(f'g TRAIN shape BEFORE stacking ({modality}):', g_train_pred_level1.shape)
        print(f'g TEST shape BEFORE stacking ({modality}):', g_test_pred_level1.shape)
        
        all_modalities_train.append(g_train_pred_level1)
        all_modalities_test.append(g_test_pred_level1)
    
    # Initialize with first modality
    features_train_level1_inner = all_modalities_train[0]
    features_train_level1_outer = all_modalities_train[0]
    features_test_level1_inner = all_modalities_test[0]
    features_test_level1_outer = all_modalities_test[0]
    
    # Stack train data with both merge types
    for i in range(1, len(all_modalities_train)):
        features_train_level1_inner = pd.merge(features_train_level1_inner, all_modalities_train[i], on='eid', how='inner')
        features_train_level1_outer = pd.merge(features_train_level1_outer, all_modalities_train[i], on='eid', how='outer')
    
    # Save stacked train data
    features_train_level1_inner.to_csv(paths['stacking_output']['train_stacked_inner'].format(fold), index=False)
    features_train_level1_outer.to_csv(paths['stacking_output']['train_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_train = pd.read_csv(paths['g_observed']['train'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_train_level1_inner_g_matched = pd.merge(features_train_level1_inner, g_observed_train, on='eid', how='inner')
    features_train_level1_inner_g_matched.to_csv(paths['stacking_output']['train_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_train_level1_outer_g_matched = pd.merge(features_train_level1_outer, g_observed_train, on='eid', how='left')
    features_train_level1_outer_g_matched.to_csv(paths['stacking_output']['train_g_matched_outer'].format(fold), index=False)
    
    print('g TRAIN shape AFTER inner stacking:', features_train_level1_inner_g_matched.shape)
    print('g TRAIN shape AFTER outer stacking:', features_train_level1_outer_g_matched.shape)
    
    # Stack test data with both merge types
    for i in range(1, len(all_modalities_test)):
        features_test_level1_inner = pd.merge(features_test_level1_inner, all_modalities_test[i], on='eid', how='inner')
        features_test_level1_outer = pd.merge(features_test_level1_outer, all_modalities_test[i], on='eid', how='outer')
    
    # Save stacked test data
    features_test_level1_inner.to_csv(paths['stacking_output']['test_stacked_inner'].format(fold), index=False)
    features_test_level1_outer.to_csv(paths['stacking_output']['test_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_test = pd.read_csv(paths['g_observed']['test'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_test_level1_inner_g_matched = pd.merge(features_test_level1_inner, g_observed_test, on='eid', how='inner')
    features_test_level1_inner_g_matched.to_csv(paths['stacking_output']['test_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_test_level1_outer_g_matched = pd.merge(features_test_level1_outer, g_observed_test, on='eid', how='left')
    features_test_level1_outer_g_matched.to_csv(paths['stacking_output']['test_g_matched_outer'].format(fold), index=False)
    
    print('g TEST shape AFTER inner stacking:', features_test_level1_inner_g_matched.shape)
    print('g TEST shape AFTER outer stacking:', features_test_level1_outer_g_matched.shape)
# Out:
# Started 0
# g TRAIN shape BEFORE stacking (amplitudes_21): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20600, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5151, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20660, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5166, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5153, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20604, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5153, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20646, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20379, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5098, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20600, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5151, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20660, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5166, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5153, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20604, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5153, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20646, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20379, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5098, 2)
# g TRAIN shape AFTER inner stacking: (20324, 20)
# g TRAIN shape AFTER outer stacking: (21520, 20)
# g TEST shape AFTER inner stacking: (5085, 20)
# g TEST shape AFTER outer stacking: (5376, 20)
# Started 1
# g TRAIN shape BEFORE stacking (amplitudes_21): (21479, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5415, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21479, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5415, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21479, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5415, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21479, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5415, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21479, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5415, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21479, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5415, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20560, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5191, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5216, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20557, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5206, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20552, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5205, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20591, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20327, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5150, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20560, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5191, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5216, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20557, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5206, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20552, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5205, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20591, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20327, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5150, 2)
# g TRAIN shape AFTER inner stacking: (20279, 20)
# g TRAIN shape AFTER outer stacking: (21481, 20)
# g TEST shape AFTER inner stacking: (5130, 20)
# g TEST shape AFTER outer stacking: (5415, 20)
# Started 2
# g TRAIN shape BEFORE stacking (amplitudes_21): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20604, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5147, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20667, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20614, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5149, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20609, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5148, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20649, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5156, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20383, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5094, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20604, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5147, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20667, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20614, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5149, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20609, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5148, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20649, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5156, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20383, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5094, 2)
# g TRAIN shape AFTER inner stacking: (20330, 20)
# g TRAIN shape AFTER outer stacking: (21518, 20)
# g TEST shape AFTER inner stacking: (5079, 20)
# g TEST shape AFTER outer stacking: (5378, 20)
# Started 3
# g TRAIN shape BEFORE stacking (amplitudes_21): (21583, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5311, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21583, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5311, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21583, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5311, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21583, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5311, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21583, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5311, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21583, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5311, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20686, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5065, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20755, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5071, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20704, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5059, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20701, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5056, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20736, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5069, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20479, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (4998, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20686, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5065, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20755, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5071, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20704, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5059, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20701, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5056, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20736, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5069, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20479, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (4998, 2)
# g TRAIN shape AFTER inner stacking: (20419, 20)
# g TRAIN shape AFTER outer stacking: (21585, 20)
# g TEST shape AFTER inner stacking: (4990, 20)
# g TEST shape AFTER outer stacking: (5311, 20)
# Started 4
# g TRAIN shape BEFORE stacking (amplitudes_21): (21478, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5416, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21478, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5416, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21478, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5416, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21478, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5416, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21478, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5416, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21478, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5416, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20554, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5197, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20612, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20567, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5196, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20562, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5195, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20598, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5207, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20340, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5137, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20554, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5197, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20612, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20567, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5196, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20562, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5195, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20598, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5207, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20340, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5137, 2)
# g TRAIN shape AFTER inner stacking: (20284, 20)
# g TRAIN shape AFTER outer stacking: (21480, 20)
# g TEST shape AFTER inner stacking: (5125, 20)
# g TEST shape AFTER outer stacking: (5416, 20)

# %%
# Analyze all folds
paths = {
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'rs',  'features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'rs', 'features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}


results = [analyze_g_matched(fold, paths) for fold in folds]
results_df = pd.DataFrame(results)
all_features_consistent = all(
    set(r['ncols Train']) == set(results[0]['ncols Train']) 
    for r in results)

print("Sample Sizes and Feature Counts:")
results_df[['Fold', 'N Train Inner', 'N Test Inner', 'N Train Outer', 'N Test Outer', 'N Features']]
# Out:
# Sample Sizes and Feature Counts:
#    Fold  N Train Inner  N Test Inner  N Train Outer  N Test Outer  N Features
# 0     0          20324          5085          21520          5376          18
# 1     1          20279          5130          21481          5415          18
# 2     2          20330          5079          21518          5378          18
# 3     3          20419          4990          21585          5311          18
# 4     4          20284          5125          21480          5416          18

# %% [markdown]
# ### All brain phenotypes

# %%
# Match features and targets
base_path = '/UK_BB/brainbody'
paths = {
    'g_pred': {
        'train': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
        'test': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
    },
    'g_observed': {
        'train': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_train_with_id_{}.csv'),
        'test': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_test_with_id_{}.csv')
    },
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri','features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}

# Add this right after the paths dictionary definition (before the folds loop)
for path_key in paths['stacking_output']:
    os.makedirs(os.path.dirname(paths['stacking_output'][path_key].format(0)), exist_ok=True)
    
# Match features and targets
folds = range(0, 5)
warnings.simplefilter(action='ignore', category=FutureWarning)

for fold in folds:
    print(f'Started {fold}', flush=True)
    all_modalities_train = []
    all_modalities_test = []
    
    for modality in modalities_mri:
        # Read train and test predictions using formatted paths
        train_path = paths['g_pred']['train'].format(fold, modality, fold)
        test_path = paths['g_pred']['test'].format(fold, modality, fold)
        
        g_train_pred_level1 = pd.read_csv(train_path)
        g_test_pred_level1 = pd.read_csv(test_path)
        
        print(f'g TRAIN shape BEFORE stacking ({modality}):', g_train_pred_level1.shape)
        print(f'g TEST shape BEFORE stacking ({modality}):', g_test_pred_level1.shape)
        
        all_modalities_train.append(g_train_pred_level1)
        all_modalities_test.append(g_test_pred_level1)
    
    # Initialize with first modality
    features_train_level1_inner = all_modalities_train[0]
    features_train_level1_outer = all_modalities_train[0]
    features_test_level1_inner = all_modalities_test[0]
    features_test_level1_outer = all_modalities_test[0]
    
    # Stack train data with both merge types
    for i in range(1, len(all_modalities_train)):
        features_train_level1_inner = pd.merge(features_train_level1_inner, all_modalities_train[i], on='eid', how='inner')
        features_train_level1_outer = pd.merge(features_train_level1_outer, all_modalities_train[i], on='eid', how='outer')
    
    # Save stacked train data
    features_train_level1_inner.to_csv(paths['stacking_output']['train_stacked_inner'].format(fold), index=False)
    features_train_level1_outer.to_csv(paths['stacking_output']['train_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_train = pd.read_csv(paths['g_observed']['train'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_train_level1_inner_g_matched = pd.merge(features_train_level1_inner, g_observed_train, on='eid', how='inner')
    features_train_level1_inner_g_matched.to_csv(paths['stacking_output']['train_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_train_level1_outer_g_matched = pd.merge(features_train_level1_outer, g_observed_train, on='eid', how='left')
    features_train_level1_outer_g_matched.to_csv(paths['stacking_output']['train_g_matched_outer'].format(fold), index=False)
    
    print('g TRAIN shape AFTER inner stacking:', features_train_level1_inner_g_matched.shape)
    print('g TRAIN shape AFTER outer stacking:', features_train_level1_outer_g_matched.shape)
    
    # Stack test data with both merge types
    for i in range(1, len(all_modalities_test)):
        features_test_level1_inner = pd.merge(features_test_level1_inner, all_modalities_test[i], on='eid', how='inner')
        features_test_level1_outer = pd.merge(features_test_level1_outer, all_modalities_test[i], on='eid', how='outer')
    
    # Save stacked test data
    features_test_level1_inner.to_csv(paths['stacking_output']['test_stacked_inner'].format(fold), index=False)
    features_test_level1_outer.to_csv(paths['stacking_output']['test_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_test = pd.read_csv(paths['g_observed']['test'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_test_level1_inner_g_matched = pd.merge(features_test_level1_inner, g_observed_test, on='eid', how='inner')
    features_test_level1_inner_g_matched.to_csv(paths['stacking_output']['test_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_test_level1_outer_g_matched = pd.merge(features_test_level1_outer, g_observed_test, on='eid', how='left')
    features_test_level1_outer_g_matched.to_csv(paths['stacking_output']['test_g_matched_outer'].format(fold), index=False)
    
    print('g TEST shape AFTER inner stacking:', features_test_level1_inner_g_matched.shape)
    print('g TEST shape AFTER outer stacking:', features_test_level1_outer_g_matched.shape)
# Out:
# Started 0
# g TRAIN shape BEFORE stacking (struct_fast): (21977, 2)
# g TEST shape BEFORE stacking (struct_fast): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21977, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21977, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21977, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21977, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21950, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5467, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21950, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5467, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21950, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5467, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21977, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21977, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21977, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5474, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21977, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5474, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21977, 2)
# g TEST shape BEFORE stacking (add_t1): (5474, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21737, 2)
# g TEST shape BEFORE stacking (add_t2): (5422, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_FA_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_FA_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_MD_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_MD_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_L1_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_L1_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_L2_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_L2_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_L3_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_L3_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_MO_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_MO_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_OD_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_OD_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_tbss): (21555, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_tbss): (5389, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_prob): (21555, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_prob): (5389, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_FA_i2): (20672, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_FA_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Length_i2): (20672, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Length_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (20672, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (20672, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (20648, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (5163, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (20648, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (5163, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (20648, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (5163, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (20648, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (5163, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (20672, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (20672, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (20672, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (20672, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (20671, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (20671, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (20671, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (20671, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (20671, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (20671, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (20671, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (20671, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (5170, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (20672, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (20672, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (20672, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (20672, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (5171, 2)
# g TRAIN shape BEFORE stacking (amplitudes_21): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20600, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5151, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20660, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5166, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5153, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20604, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5153, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20646, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20379, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5098, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20600, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5151, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20660, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5166, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5153, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20604, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5153, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20646, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20379, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5098, 2)
# g TRAIN shape AFTER inner stacking: (20273, 83)
# g TRAIN shape AFTER outer stacking: (22210, 83)
# g TEST shape AFTER inner stacking: (5073, 83)
# g TEST shape AFTER outer stacking: (5539, 83)
# Started 1
# g TRAIN shape BEFORE stacking (struct_fast): (21920, 2)
# g TEST shape BEFORE stacking (struct_fast): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21920, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21920, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21920, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21920, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21896, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5521, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21896, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5521, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21896, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5521, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21920, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21920, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21920, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21920, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5531, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21920, 2)
# g TEST shape BEFORE stacking (add_t1): (5531, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21689, 2)
# g TEST shape BEFORE stacking (add_t2): (5470, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_FA_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_FA_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_MD_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_MD_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_L1_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_L1_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_L2_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_L2_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_L3_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_L3_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_MO_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_MO_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_OD_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_OD_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_tbss): (21518, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_tbss): (5426, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_prob): (21518, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_prob): (5426, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_FA_i2): (20626, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_FA_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Length_i2): (20626, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Length_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (20626, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (20626, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (20604, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (5207, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (20604, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (5207, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (20604, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (5207, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (20604, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (5207, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (5217, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (20623, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (20623, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (20623, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (20623, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (20623, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (20623, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (20623, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (20623, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (20625, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (20625, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (20625, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (20625, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (5218, 2)
# g TRAIN shape BEFORE stacking (amplitudes_21): (21479, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5415, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21479, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5415, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21479, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5415, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21479, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5415, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21479, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5415, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21479, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5415, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20560, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5191, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5216, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20557, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5206, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20552, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5205, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20591, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20327, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5150, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20560, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5191, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20610, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5216, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20557, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5206, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20552, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5205, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20591, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20327, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5150, 2)
# g TRAIN shape AFTER inner stacking: (20231, 83)
# g TRAIN shape AFTER outer stacking: (22156, 83)
# g TEST shape AFTER inner stacking: (5115, 83)
# g TEST shape AFTER outer stacking: (5593, 83)
# Started 2
# g TRAIN shape BEFORE stacking (struct_fast): (21965, 2)
# g TEST shape BEFORE stacking (struct_fast): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21965, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21965, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21965, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21965, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21937, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5480, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21937, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5480, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21937, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5480, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21965, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21965, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21965, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5486, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21965, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5486, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21965, 2)
# g TEST shape BEFORE stacking (add_t1): (5486, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21730, 2)
# g TEST shape BEFORE stacking (add_t2): (5429, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_FA_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_FA_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_MD_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_MD_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_L1_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_L1_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_L2_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_L2_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_L3_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_L3_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_MO_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_MO_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_OD_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_OD_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_tbss): (21556, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_tbss): (5388, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_prob): (21556, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_prob): (5388, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_FA_i2): (20677, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_FA_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Length_i2): (20677, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Length_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (20677, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (20677, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (20650, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (5161, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (20650, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (5161, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (20650, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (5161, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (20650, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (5161, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (20677, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (20677, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (20677, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (20677, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (20675, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (20675, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (20675, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (20675, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (20675, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (20675, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (20675, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (20675, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (20677, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (20677, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (20677, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (20677, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (5166, 2)
# g TRAIN shape BEFORE stacking (amplitudes_21): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5376, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21518, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21518, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5376, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20604, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5147, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20667, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20614, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5149, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20609, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5148, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20649, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5156, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20383, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5094, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20604, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5147, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20667, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5159, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20614, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5149, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20609, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5148, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20649, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5156, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20383, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5094, 2)
# g TRAIN shape AFTER inner stacking: (20275, 83)
# g TRAIN shape AFTER outer stacking: (22202, 83)
# g TEST shape AFTER inner stacking: (5071, 83)
# g TEST shape AFTER outer stacking: (5547, 83)
# Started 3
# g TRAIN shape BEFORE stacking (struct_fast): (22031, 2)
# g TEST shape BEFORE stacking (struct_fast): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (22031, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (22031, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (22031, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (22031, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21999, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5418, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21999, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5418, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21999, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5418, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (22031, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (22031, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (22031, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5420, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (22031, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5420, 2)
# g TRAIN shape BEFORE stacking (add_t1): (22031, 2)
# g TEST shape BEFORE stacking (add_t1): (5420, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21792, 2)
# g TEST shape BEFORE stacking (add_t2): (5367, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_FA_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_FA_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_MD_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_MD_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_L1_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_L1_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_L2_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_L2_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_L3_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_L3_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_MO_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_MO_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_OD_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_OD_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_tbss): (21626, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_tbss): (5318, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_prob): (21626, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_prob): (5318, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_FA_i2): (20770, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_FA_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Length_i2): (20770, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Length_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (20770, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (20770, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (20740, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (5071, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (20740, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (5071, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (20740, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (5071, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (20740, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (5071, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (20770, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (20770, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (20770, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (20770, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (20769, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (20769, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (20769, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (20769, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (20769, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (20769, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (20769, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (20769, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (5072, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (20770, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (20770, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (20770, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (20770, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (5073, 2)
# g TRAIN shape BEFORE stacking (amplitudes_21): (21583, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5311, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21583, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5311, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21583, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5311, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21583, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5311, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21583, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5311, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21583, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5311, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20686, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5065, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20755, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5071, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20704, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5059, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20701, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5056, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20736, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5069, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20479, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (4998, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20686, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5065, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20755, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5071, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20704, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5059, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20701, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5056, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20736, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5069, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20479, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (4998, 2)
# g TRAIN shape AFTER inner stacking: (20373, 83)
# g TRAIN shape AFTER outer stacking: (22265, 83)
# g TEST shape AFTER inner stacking: (4973, 83)
# g TEST shape AFTER outer stacking: (5484, 83)
# Started 4
# g TRAIN shape BEFORE stacking (struct_fast): (21911, 2)
# g TEST shape BEFORE stacking (struct_fast): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_sub_first): (21911, 2)
# g TEST shape BEFORE stacking (struct_sub_first): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_mean_intensity): (21911, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_mean_intensity): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_fs_aseg_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_fs_aseg_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_area): (21911, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_area): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (21911, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_mean_thickness): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_ba_exvivo_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_ba_exvivo_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_area): (21886, 2)
# g TEST shape BEFORE stacking (struct_a2009s_area): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_mean_thickness): (21886, 2)
# g TEST shape BEFORE stacking (struct_a2009s_mean_thickness): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_a2009s_volume): (21886, 2)
# g TEST shape BEFORE stacking (struct_a2009s_volume): (5531, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_area): (21911, 2)
# g TEST shape BEFORE stacking (struct_dkt_area): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_mean_thickness): (21911, 2)
# g TEST shape BEFORE stacking (struct_dkt_mean_thickness): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_dkt_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_dkt_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_gw): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_gw): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_pial): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_pial): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_area): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_area): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_mean_thickness): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_mean_thickness): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_desikan_white_volume): (21911, 2)
# g TEST shape BEFORE stacking (struct_desikan_white_volume): (5540, 2)
# g TRAIN shape BEFORE stacking (struct_subsegmentation): (21911, 2)
# g TEST shape BEFORE stacking (struct_subsegmentation): (5540, 2)
# g TRAIN shape BEFORE stacking (add_t1): (21911, 2)
# g TEST shape BEFORE stacking (add_t1): (5540, 2)
# g TRAIN shape BEFORE stacking (add_t2): (21688, 2)
# g TEST shape BEFORE stacking (add_t2): (5471, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_FA_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_FA_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_FA_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_MD_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_MD_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_MD_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_L1_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_L1_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_L1_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_L2_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_L2_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_L2_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_L3_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_L3_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_L3_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_MO_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_MO_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_MO_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_OD_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_OD_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_OD_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_ICVF_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_ICVF_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_tbss): (21521, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_tbss): (5423, 2)
# g TRAIN shape BEFORE stacking (dwi_ISOVF_prob): (21521, 2)
# g TEST shape BEFORE stacking (dwi_ISOVF_prob): (5423, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_FA_i2): (20627, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_FA_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Length_i2): (20627, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Length_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (20627, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_SIFT2_FBC_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (20627, 2)
# g TEST shape BEFORE stacking (aparc_Tian_S1_Streamline_Count_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (20602, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_FA_i2): (5209, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (20602, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Length_i2): (5209, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (20602, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_SIFT2_FBC_i2): (5209, 2)
# g TRAIN shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (20602, 2)
# g TEST shape BEFORE stacking (aparc_a2009s_Tian_S1_Streamline_Count_i2): (5209, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (20627, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_FA_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (20627, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Length_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (20627, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_SIFT2_FBC_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (20627, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S1_Streamline_Count_i2): (5216, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_FA_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Length_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_SIFT2_FBC_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (20626, 2)
# g TEST shape BEFORE stacking (Glasser_Tian_S4_Streamline_Count_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (20626, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_FA_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (20626, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Length_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (20626, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_SIFT2_FBC_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (20626, 2)
# g TEST shape BEFORE stacking (Schaefer7n200p_Tian_S1_Streamline_Count_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (20628, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_FA_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (20628, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Length_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (20628, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (20628, 2)
# g TEST shape BEFORE stacking (Schaefer7n1000p_Tian_S4_Streamline_Count_i2): (5215, 2)
# g TRAIN shape BEFORE stacking (amplitudes_21): (21478, 2)
# g TEST shape BEFORE stacking (amplitudes_21): (5416, 2)
# g TRAIN shape BEFORE stacking (full_correlation_21): (21478, 2)
# g TEST shape BEFORE stacking (full_correlation_21): (5416, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_21): (21478, 2)
# g TEST shape BEFORE stacking (partial_correlation_21): (5416, 2)
# g TRAIN shape BEFORE stacking (amplitudes_55): (21478, 2)
# g TEST shape BEFORE stacking (amplitudes_55): (5416, 2)
# g TRAIN shape BEFORE stacking (full_correlation_55): (21478, 2)
# g TEST shape BEFORE stacking (full_correlation_55): (5416, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_55): (21478, 2)
# g TEST shape BEFORE stacking (partial_correlation_55): (5416, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (20554, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_a2009s_Tian_S1): (5197, 2)
# g TRAIN shape BEFORE stacking (full_correlation_aparc_Tian_S1): (20612, 2)
# g TEST shape BEFORE stacking (full_correlation_aparc_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (20567, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S1): (5196, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (20562, 2)
# g TEST shape BEFORE stacking (full_correlation_Glasser_Tian_S4): (5195, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (20598, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n200p_Tian_S1): (5207, 2)
# g TRAIN shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (20340, 2)
# g TEST shape BEFORE stacking (full_correlation_Schaefer7n500p_Tian_S4): (5137, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (20554, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_a2009s_Tian_S1): (5197, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (20612, 2)
# g TEST shape BEFORE stacking (partial_correlation_aparc_Tian_S1): (5214, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (20567, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S1): (5196, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (20562, 2)
# g TEST shape BEFORE stacking (partial_correlation_Glasser_Tian_S4): (5195, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (20598, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n200p_Tian_S1): (5207, 2)
# g TRAIN shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (20340, 2)
# g TEST shape BEFORE stacking (partial_correlation_Schaefer7n500p_Tian_S4): (5137, 2)
# g TRAIN shape AFTER inner stacking: (20232, 83)
# g TRAIN shape AFTER outer stacking: (22163, 83)
# g TEST shape AFTER inner stacking: (5114, 83)
# g TEST shape AFTER outer stacking: (5586, 83)

# %%
# Analyze all folds
paths = {
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_train_level1_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri',  'features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_train_level1_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_test_level1_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain', 'allmri', 'features_test_level1_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}


results = [analyze_g_matched(fold, paths) for fold in folds]
results_df = pd.DataFrame(results)
all_features_consistent = all(
    set(r['ncols Train']) == set(results[0]['ncols Train']) 
    for r in results)

print("Sample Sizes and Feature Counts:")
results_df[['Fold', 'N Train Inner', 'N Test Inner', 'N Train Outer', 'N Test Outer', 'N Features']]
# Out:
# Sample Sizes and Feature Counts:
#    Fold  N Train Inner  N Test Inner  N Train Outer  N Test Outer  N Features
# 0     0          20273          5073          22210          5539          81
# 1     1          20231          5115          22156          5593          81
# 2     2          20275          5071          22202          5547          81
# 3     3          20373          4973          22265          5484          81
# 4     4          20232          5114          22163          5586          81

# %% [markdown]
# ## Body

# %%
# Define modalities
###############################################################
modalities_body = [
'immune',
'renalhepatic',
'metabolic',
'cardiopulmonary',
'musculoskeletal',
'bone_densitometry',
'pwa',
'heart_mri',
'carotid_ultrasound',
'arterial_stiffness',
'ecg_rest',
'body_composition_by_impedance',
'body_composition_dxa',
'bone_dxa',
'kidneys_mri',
'liver_mri',
'abdominal_composition_mri_18_vars', #17 vars
'abdominal_organ_composition_mri_13_vars', #12 vars
'hearing'
]

body_composition = [
'body_composition_by_impedance',
'bone_dxa',
'abdominal_composition_mri_18_vars', #17 vars
'body_composition_dxa',
'abdominal_organ_composition_mri_13_vars', #12 vars
'bone_densitometry',
'musculoskeletal',
]

cardiopulmonary = [
'cardiopulmonary',
'pwa',
'carotid_ultrasound',
'heart_mri',
'arterial_stiffness',
'ecg_rest'
]

renal_hepatic = [
'renalhepatic',
'kidneys_mri',
'liver_mri',]

immune = ['immune']
metabolic = ['metabolic']
hearing = ['hearing']

# %%
# Match features and targets
base_path = '/UK_BB/brainbody'
paths = {
    'g_pred': {
        'train': os.path.join(base_path, 'lifestyle-envir-body', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
        'test': os.path.join(base_path, 'lifestyle-envir-body', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
    },
    'g_observed': {
        'train': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_train_with_id_{}.csv'),
        'test': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_test_with_id_{}.csv')
    },
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking',  'body', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'body','features_train_level1_stacked_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking',  'body','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'body','features_train_level1_stacked_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'body','features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'body','features_test_level1_stacked_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking',  'body','features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'body','features_test_level1_stacked_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}
for path_key in paths['stacking_output']:
    os.makedirs(os.path.dirname(paths['stacking_output'][path_key].format(0)), exist_ok=True)
    
# Match features and targets
folds = range(0, 5)
warnings.simplefilter(action='ignore', category=FutureWarning)

for fold in folds:
    print(f'Started {fold}', flush=True)
    all_modalities_train = []
    all_modalities_test = []
    
    for modality in modalities_body:
        # Read train and test predictions using formatted paths
        train_path = paths['g_pred']['train'].format(fold, modality, fold)
        test_path = paths['g_pred']['test'].format(fold, modality, fold)
        
        g_train_pred_level1 = pd.read_csv(train_path)
        g_test_pred_level1 = pd.read_csv(test_path)
        
        print(f'g TRAIN shape BEFORE stacking ({modality}):', g_train_pred_level1.shape)
        print(f'g TEST shape BEFORE stacking ({modality}):', g_test_pred_level1.shape)
        
        all_modalities_train.append(g_train_pred_level1)
        all_modalities_test.append(g_test_pred_level1)
    
    # Initialize with first modality
    features_train_level1_inner = all_modalities_train[0]
    features_train_level1_outer = all_modalities_train[0]
    features_test_level1_inner = all_modalities_test[0]
    features_test_level1_outer = all_modalities_test[0]
    
    # Stack train data with both merge types
    for i in range(1, len(all_modalities_train)):
        features_train_level1_inner = pd.merge(features_train_level1_inner, all_modalities_train[i], on='eid', how='inner')
        features_train_level1_outer = pd.merge(features_train_level1_outer, all_modalities_train[i], on='eid', how='outer')
    
    # Save stacked train data
    features_train_level1_inner.to_csv(paths['stacking_output']['train_stacked_inner'].format(fold), index=False)
    features_train_level1_outer.to_csv(paths['stacking_output']['train_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_train = pd.read_csv(paths['g_observed']['train'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_train_level1_inner_g_matched = pd.merge(features_train_level1_inner, g_observed_train, on='eid', how='inner')
    features_train_level1_inner_g_matched.to_csv(paths['stacking_output']['train_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_train_level1_outer_g_matched = pd.merge(features_train_level1_outer, g_observed_train, on='eid', how='left')
    features_train_level1_outer_g_matched.to_csv(paths['stacking_output']['train_g_matched_outer'].format(fold), index=False)
    
    print('g TRAIN shape AFTER inner stacking:', features_train_level1_inner_g_matched.shape)
    print('g TRAIN shape AFTER outer stacking:', features_train_level1_outer_g_matched.shape)
    
    # Stack test data with both merge types
    for i in range(1, len(all_modalities_test)):
        features_test_level1_inner = pd.merge(features_test_level1_inner, all_modalities_test[i], on='eid', how='inner')
        features_test_level1_outer = pd.merge(features_test_level1_outer, all_modalities_test[i], on='eid', how='outer')
    
    # Save stacked test data
    features_test_level1_inner.to_csv(paths['stacking_output']['test_stacked_inner'].format(fold), index=False)
    features_test_level1_outer.to_csv(paths['stacking_output']['test_stacked_outer'].format(fold), index=False)
    
    # Match to observed g (both inner and outer versions)
    g_observed_test = pd.read_csv(paths['g_observed']['test'].format(fold, fold))
    
    # Inner merge with g observed (removes NAs)
    features_test_level1_inner_g_matched = pd.merge(features_test_level1_inner, g_observed_test, on='eid', how='inner')
    features_test_level1_inner_g_matched.to_csv(paths['stacking_output']['test_g_matched_inner'].format(fold), index=False)
    
    # Outer merge with g observed (keeps all eids)
    features_test_level1_outer_g_matched = pd.merge(features_test_level1_outer, g_observed_test, on='eid', how='left')
    features_test_level1_outer_g_matched.to_csv(paths['stacking_output']['test_g_matched_outer'].format(fold), index=False)
    
    print('g TEST shape AFTER inner stacking:', features_test_level1_inner_g_matched.shape)
    print('g TEST shape AFTER outer stacking:', features_test_level1_outer_g_matched.shape)
# Out:
# Started 0
# g TRAIN shape BEFORE stacking (immune): (22911, 2)
# g TEST shape BEFORE stacking (immune): (5738, 2)
# g TRAIN shape BEFORE stacking (renalhepatic): (18407, 2)
# g TEST shape BEFORE stacking (renalhepatic): (4598, 2)
# g TRAIN shape BEFORE stacking (metabolic): (14548, 2)
# g TEST shape BEFORE stacking (metabolic): (3572, 2)
# g TRAIN shape BEFORE stacking (cardiopulmonary): (16285, 2)
# g TEST shape BEFORE stacking (cardiopulmonary): (4116, 2)
# g TRAIN shape BEFORE stacking (musculoskeletal): (14558, 2)
# g TEST shape BEFORE stacking (musculoskeletal): (3701, 2)
# g TRAIN shape BEFORE stacking (bone_densitometry): (13957, 2)
# g TEST shape BEFORE stacking (bone_densitometry): (3535, 2)
# g TRAIN shape BEFORE stacking (pwa): (19418, 2)
# g TEST shape BEFORE stacking (pwa): (4821, 2)
# g TRAIN shape BEFORE stacking (heart_mri): (19704, 2)
# g TEST shape BEFORE stacking (heart_mri): (5002, 2)
# g TRAIN shape BEFORE stacking (carotid_ultrasound): (23976, 2)
# g TEST shape BEFORE stacking (carotid_ultrasound): (5995, 2)
# g TRAIN shape BEFORE stacking (arterial_stiffness): (20063, 2)
# g TEST shape BEFORE stacking (arterial_stiffness): (5043, 2)
# g TRAIN shape BEFORE stacking (ecg_rest): (20708, 2)
# g TEST shape BEFORE stacking (ecg_rest): (5188, 2)
# g TRAIN shape BEFORE stacking (body_composition_by_impedance): (23912, 2)
# g TEST shape BEFORE stacking (body_composition_by_impedance): (5966, 2)
# g TRAIN shape BEFORE stacking (body_composition_dxa): (18163, 2)
# g TEST shape BEFORE stacking (body_composition_dxa): (4637, 2)
# g TRAIN shape BEFORE stacking (bone_dxa): (20703, 2)
# g TEST shape BEFORE stacking (bone_dxa): (5172, 2)
# g TRAIN shape BEFORE stacking (kidneys_mri): (18690, 2)
# g TEST shape BEFORE stacking (kidneys_mri): (4761, 2)
# g TRAIN shape BEFORE stacking (liver_mri): (20368, 2)
# g TEST shape BEFORE stacking (liver_mri): (5147, 2)
# g TRAIN shape BEFORE stacking (abdominal_composition_mri_18_vars): (19649, 2)
# g TEST shape BEFORE stacking (abdominal_composition_mri_18_vars): (4976, 2)
# g TRAIN shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (16901, 2)
# g TEST shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (4305, 2)
# g TRAIN shape BEFORE stacking (hearing): (24773, 2)
# g TEST shape BEFORE stacking (hearing): (6198, 2)
# g TRAIN shape AFTER inner stacking: (1109, 21)
# g TRAIN shape AFTER outer stacking: (25517, 21)
# g TEST shape AFTER inner stacking: (323, 21)
# g TEST shape AFTER outer stacking: (6380, 21)
# Started 1
# g TRAIN shape BEFORE stacking (immune): (22897, 2)
# g TEST shape BEFORE stacking (immune): (5752, 2)
# g TRAIN shape BEFORE stacking (renalhepatic): (18376, 2)
# g TEST shape BEFORE stacking (renalhepatic): (4629, 2)
# g TRAIN shape BEFORE stacking (metabolic): (14493, 2)
# g TEST shape BEFORE stacking (metabolic): (3627, 2)
# g TRAIN shape BEFORE stacking (cardiopulmonary): (16321, 2)
# g TEST shape BEFORE stacking (cardiopulmonary): (4080, 2)
# g TRAIN shape BEFORE stacking (musculoskeletal): (14633, 2)
# g TEST shape BEFORE stacking (musculoskeletal): (3626, 2)
# g TRAIN shape BEFORE stacking (bone_densitometry): (13945, 2)
# g TEST shape BEFORE stacking (bone_densitometry): (3547, 2)
# g TRAIN shape BEFORE stacking (pwa): (19370, 2)
# g TEST shape BEFORE stacking (pwa): (4869, 2)
# g TRAIN shape BEFORE stacking (heart_mri): (19773, 2)
# g TEST shape BEFORE stacking (heart_mri): (4933, 2)
# g TRAIN shape BEFORE stacking (carotid_ultrasound): (23983, 2)
# g TEST shape BEFORE stacking (carotid_ultrasound): (5988, 2)
# g TRAIN shape BEFORE stacking (arterial_stiffness): (20105, 2)
# g TEST shape BEFORE stacking (arterial_stiffness): (5001, 2)
# g TRAIN shape BEFORE stacking (ecg_rest): (20724, 2)
# g TEST shape BEFORE stacking (ecg_rest): (5172, 2)
# g TRAIN shape BEFORE stacking (body_composition_by_impedance): (23895, 2)
# g TEST shape BEFORE stacking (body_composition_by_impedance): (5983, 2)
# g TRAIN shape BEFORE stacking (body_composition_dxa): (18304, 2)
# g TEST shape BEFORE stacking (body_composition_dxa): (4496, 2)
# g TRAIN shape BEFORE stacking (bone_dxa): (20701, 2)
# g TEST shape BEFORE stacking (bone_dxa): (5174, 2)
# g TRAIN shape BEFORE stacking (kidneys_mri): (18753, 2)
# g TEST shape BEFORE stacking (kidneys_mri): (4698, 2)
# g TRAIN shape BEFORE stacking (liver_mri): (20416, 2)
# g TEST shape BEFORE stacking (liver_mri): (5099, 2)
# g TRAIN shape BEFORE stacking (abdominal_composition_mri_18_vars): (19727, 2)
# g TEST shape BEFORE stacking (abdominal_composition_mri_18_vars): (4898, 2)
# g TRAIN shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (16973, 2)
# g TEST shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (4233, 2)
# g TRAIN shape BEFORE stacking (hearing): (24786, 2)
# g TEST shape BEFORE stacking (hearing): (6185, 2)
# g TRAIN shape AFTER inner stacking: (1165, 21)
# g TRAIN shape AFTER outer stacking: (25517, 21)
# g TEST shape AFTER inner stacking: (267, 21)
# g TEST shape AFTER outer stacking: (6380, 21)
# Started 2
# g TRAIN shape BEFORE stacking (immune): (22947, 2)
# g TEST shape BEFORE stacking (immune): (5702, 2)
# g TRAIN shape BEFORE stacking (renalhepatic): (18424, 2)
# g TEST shape BEFORE stacking (renalhepatic): (4581, 2)
# g TRAIN shape BEFORE stacking (metabolic): (14520, 2)
# g TEST shape BEFORE stacking (metabolic): (3600, 2)
# g TRAIN shape BEFORE stacking (cardiopulmonary): (16345, 2)
# g TEST shape BEFORE stacking (cardiopulmonary): (4056, 2)
# g TRAIN shape BEFORE stacking (musculoskeletal): (14643, 2)
# g TEST shape BEFORE stacking (musculoskeletal): (3616, 2)
# g TRAIN shape BEFORE stacking (bone_densitometry): (14025, 2)
# g TEST shape BEFORE stacking (bone_densitometry): (3467, 2)
# g TRAIN shape BEFORE stacking (pwa): (19378, 2)
# g TEST shape BEFORE stacking (pwa): (4861, 2)
# g TRAIN shape BEFORE stacking (heart_mri): (19748, 2)
# g TEST shape BEFORE stacking (heart_mri): (4958, 2)
# g TRAIN shape BEFORE stacking (carotid_ultrasound): (23962, 2)
# g TEST shape BEFORE stacking (carotid_ultrasound): (6009, 2)
# g TRAIN shape BEFORE stacking (arterial_stiffness): (20099, 2)
# g TEST shape BEFORE stacking (arterial_stiffness): (5007, 2)
# g TRAIN shape BEFORE stacking (ecg_rest): (20735, 2)
# g TEST shape BEFORE stacking (ecg_rest): (5161, 2)
# g TRAIN shape BEFORE stacking (body_composition_by_impedance): (23923, 2)
# g TEST shape BEFORE stacking (body_composition_by_impedance): (5955, 2)
# g TRAIN shape BEFORE stacking (body_composition_dxa): (18275, 2)
# g TEST shape BEFORE stacking (body_composition_dxa): (4525, 2)
# g TRAIN shape BEFORE stacking (bone_dxa): (20698, 2)
# g TEST shape BEFORE stacking (bone_dxa): (5177, 2)
# g TRAIN shape BEFORE stacking (kidneys_mri): (18748, 2)
# g TEST shape BEFORE stacking (kidneys_mri): (4703, 2)
# g TRAIN shape BEFORE stacking (liver_mri): (20396, 2)
# g TEST shape BEFORE stacking (liver_mri): (5119, 2)
# g TRAIN shape BEFORE stacking (abdominal_composition_mri_18_vars): (19675, 2)
# g TEST shape BEFORE stacking (abdominal_composition_mri_18_vars): (4950, 2)
# g TRAIN shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (16986, 2)
# g TEST shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (4220, 2)
# g TRAIN shape BEFORE stacking (hearing): (24780, 2)
# g TEST shape BEFORE stacking (hearing): (6191, 2)
# g TRAIN shape AFTER inner stacking: (1169, 21)
# g TRAIN shape AFTER outer stacking: (25518, 21)
# g TEST shape AFTER inner stacking: (263, 21)
# g TEST shape AFTER outer stacking: (6379, 21)
# Started 3
# g TRAIN shape BEFORE stacking (immune): (22914, 2)
# g TEST shape BEFORE stacking (immune): (5735, 2)
# g TRAIN shape BEFORE stacking (renalhepatic): (18394, 2)
# g TEST shape BEFORE stacking (renalhepatic): (4611, 2)
# g TRAIN shape BEFORE stacking (metabolic): (14461, 2)
# g TEST shape BEFORE stacking (metabolic): (3659, 2)
# g TRAIN shape BEFORE stacking (cardiopulmonary): (16338, 2)
# g TEST shape BEFORE stacking (cardiopulmonary): (4063, 2)
# g TRAIN shape BEFORE stacking (musculoskeletal): (14595, 2)
# g TEST shape BEFORE stacking (musculoskeletal): (3664, 2)
# g TRAIN shape BEFORE stacking (bone_densitometry): (14052, 2)
# g TEST shape BEFORE stacking (bone_densitometry): (3440, 2)
# g TRAIN shape BEFORE stacking (pwa): (19421, 2)
# g TEST shape BEFORE stacking (pwa): (4818, 2)
# g TRAIN shape BEFORE stacking (heart_mri): (19829, 2)
# g TEST shape BEFORE stacking (heart_mri): (4877, 2)
# g TRAIN shape BEFORE stacking (carotid_ultrasound): (23993, 2)
# g TEST shape BEFORE stacking (carotid_ultrasound): (5978, 2)
# g TRAIN shape BEFORE stacking (arterial_stiffness): (20063, 2)
# g TEST shape BEFORE stacking (arterial_stiffness): (5043, 2)
# g TRAIN shape BEFORE stacking (ecg_rest): (20670, 2)
# g TEST shape BEFORE stacking (ecg_rest): (5226, 2)
# g TRAIN shape BEFORE stacking (body_composition_by_impedance): (23878, 2)
# g TEST shape BEFORE stacking (body_composition_by_impedance): (6000, 2)
# g TRAIN shape BEFORE stacking (body_composition_dxa): (18189, 2)
# g TEST shape BEFORE stacking (body_composition_dxa): (4611, 2)
# g TRAIN shape BEFORE stacking (bone_dxa): (20669, 2)
# g TEST shape BEFORE stacking (bone_dxa): (5206, 2)
# g TRAIN shape BEFORE stacking (kidneys_mri): (18832, 2)
# g TEST shape BEFORE stacking (kidneys_mri): (4619, 2)
# g TRAIN shape BEFORE stacking (liver_mri): (20430, 2)
# g TEST shape BEFORE stacking (liver_mri): (5085, 2)
# g TRAIN shape BEFORE stacking (abdominal_composition_mri_18_vars): (19739, 2)
# g TEST shape BEFORE stacking (abdominal_composition_mri_18_vars): (4886, 2)
# g TRAIN shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (16948, 2)
# g TEST shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (4258, 2)
# g TRAIN shape BEFORE stacking (hearing): (24768, 2)
# g TEST shape BEFORE stacking (hearing): (6203, 2)
# g TRAIN shape AFTER inner stacking: (1136, 21)
# g TRAIN shape AFTER outer stacking: (25518, 21)
# g TEST shape AFTER inner stacking: (296, 21)
# g TEST shape AFTER outer stacking: (6379, 21)
# Started 4
# g TRAIN shape BEFORE stacking (immune): (22927, 2)
# g TEST shape BEFORE stacking (immune): (5722, 2)
# g TRAIN shape BEFORE stacking (renalhepatic): (18419, 2)
# g TEST shape BEFORE stacking (renalhepatic): (4586, 2)
# g TRAIN shape BEFORE stacking (metabolic): (14458, 2)
# g TEST shape BEFORE stacking (metabolic): (3662, 2)
# g TRAIN shape BEFORE stacking (cardiopulmonary): (16315, 2)
# g TEST shape BEFORE stacking (cardiopulmonary): (4086, 2)
# g TRAIN shape BEFORE stacking (musculoskeletal): (14607, 2)
# g TEST shape BEFORE stacking (musculoskeletal): (3652, 2)
# g TRAIN shape BEFORE stacking (bone_densitometry): (13989, 2)
# g TEST shape BEFORE stacking (bone_densitometry): (3503, 2)
# g TRAIN shape BEFORE stacking (pwa): (19369, 2)
# g TEST shape BEFORE stacking (pwa): (4870, 2)
# g TRAIN shape BEFORE stacking (heart_mri): (19770, 2)
# g TEST shape BEFORE stacking (heart_mri): (4936, 2)
# g TRAIN shape BEFORE stacking (carotid_ultrasound): (23970, 2)
# g TEST shape BEFORE stacking (carotid_ultrasound): (6001, 2)
# g TRAIN shape BEFORE stacking (arterial_stiffness): (20094, 2)
# g TEST shape BEFORE stacking (arterial_stiffness): (5012, 2)
# g TRAIN shape BEFORE stacking (ecg_rest): (20747, 2)
# g TEST shape BEFORE stacking (ecg_rest): (5149, 2)
# g TRAIN shape BEFORE stacking (body_composition_by_impedance): (23904, 2)
# g TEST shape BEFORE stacking (body_composition_by_impedance): (5974, 2)
# g TRAIN shape BEFORE stacking (body_composition_dxa): (18269, 2)
# g TEST shape BEFORE stacking (body_composition_dxa): (4531, 2)
# g TRAIN shape BEFORE stacking (bone_dxa): (20729, 2)
# g TEST shape BEFORE stacking (bone_dxa): (5146, 2)
# g TRAIN shape BEFORE stacking (kidneys_mri): (18781, 2)
# g TEST shape BEFORE stacking (kidneys_mri): (4670, 2)
# g TRAIN shape BEFORE stacking (liver_mri): (20450, 2)
# g TEST shape BEFORE stacking (liver_mri): (5065, 2)
# g TRAIN shape BEFORE stacking (abdominal_composition_mri_18_vars): (19710, 2)
# g TEST shape BEFORE stacking (abdominal_composition_mri_18_vars): (4915, 2)
# g TRAIN shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (17016, 2)
# g TEST shape BEFORE stacking (abdominal_organ_composition_mri_13_vars): (4190, 2)
# g TRAIN shape BEFORE stacking (hearing): (24777, 2)
# g TEST shape BEFORE stacking (hearing): (6194, 2)
# g TRAIN shape AFTER inner stacking: (1149, 21)
# g TRAIN shape AFTER outer stacking: (25518, 21)
# g TEST shape AFTER inner stacking: (283, 21)
# g TEST shape AFTER outer stacking: (6379, 21)

# %%
# Analyze all folds
paths = {
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'body', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'body', 'features_train_level1_stacked_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'body','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'body', 'features_train_level1_stacked_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'body', 'features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'body', 'features_test_level1_stacked_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'body', 'features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'body', 'features_test_level1_stacked_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}
folds = range(0, 5)
results = [analyze_g_matched(fold, paths) for fold in folds]
results_df = pd.DataFrame(results)
all_features_consistent = all(
    set(r['ncols Train']) == set(results[0]['ncols Train']) 
    for r in results)

print("Sample Sizes and Feature Counts:")
results_df[['Fold', 'N Train Inner', 'N Test Inner', 'N Train Outer', 'N Test Outer', 'N Features']]
# Out:
# Sample Sizes and Feature Counts:
#    Fold  N Train Inner  N Test Inner  N Train Outer  N Test Outer  N Features
# 0     0           1109           323          25517          6380          19
# 1     1           1165           267          25517          6380          19
# 2     2           1169           263          25518          6379          19
# 3     3           1136           296          25518          6379          19
# 4     4           1149           283          25518          6379          19

# %% [markdown]
# ## Body and brain

# %%
# Define modalities
###############################################################
modalities_brain_body = [
'immune',
'renalhepatic',
'metabolic',
'cardiopulmonary',
'musculoskeletal',
'bone_densitometry',
'pwa',
'heart_mri',
'carotid_ultrasound',
'arterial_stiffness',
'ecg_rest',
'body_composition_by_impedance',
'body_composition_dxa',
'bone_dxa',
'kidneys_mri',
'liver_mri',
'abdominal_composition_mri_18_vars', #17 vars
'abdominal_organ_composition_mri_13_vars', #12 vars
'hearing',

'struct_fast',
'struct_sub_first',
'struct_fs_aseg_mean_intensity',
'struct_fs_aseg_volume',
'struct_ba_exvivo_area', 
'struct_ba_exvivo_mean_thickness',
'struct_ba_exvivo_volume',
'struct_a2009s_area',
'struct_a2009s_mean_thickness',
'struct_a2009s_volume',
'struct_dkt_area',
'struct_dkt_mean_thickness',
'struct_dkt_volume',
'struct_desikan_gw',
'struct_desikan_pial',
'struct_desikan_white_area',
'struct_desikan_white_mean_thickness',
'struct_desikan_white_volume',
'struct_subsegmentation',
'add_t1',
'add_t2',

"dwi_FA_tbss", "dwi_FA_prob",
"dwi_MD_tbss", "dwi_MD_prob",
"dwi_L1_tbss", "dwi_L1_prob",
"dwi_L2_tbss", "dwi_L2_prob",
"dwi_L3_tbss", "dwi_L3_prob",
"dwi_MO_tbss", "dwi_MO_prob",
"dwi_OD_tbss", "dwi_OD_prob",
"dwi_ICVF_tbss", "dwi_ICVF_prob",
"dwi_ISOVF_tbss", "dwi_ISOVF_prob",

'aparc_Tian_S1_FA_i2',
'aparc_Tian_S1_Length_i2',
'aparc_Tian_S1_SIFT2_FBC_i2',
'aparc_Tian_S1_Streamline_Count_i2',

'aparc_a2009s_Tian_S1_FA_i2',
'aparc_a2009s_Tian_S1_Length_i2',
'aparc_a2009s_Tian_S1_SIFT2_FBC_i2',
'aparc_a2009s_Tian_S1_Streamline_Count_i2',

'Glasser_Tian_S1_FA_i2',
'Glasser_Tian_S1_Length_i2',
'Glasser_Tian_S1_SIFT2_FBC_i2',
'Glasser_Tian_S1_Streamline_Count_i2',

'Glasser_Tian_S4_FA_i2',
'Glasser_Tian_S4_Length_i2',
'Glasser_Tian_S4_SIFT2_FBC_i2',
'Glasser_Tian_S4_Streamline_Count_i2',

'Schaefer7n200p_Tian_S1_FA_i2',
'Schaefer7n200p_Tian_S1_Length_i2',
'Schaefer7n200p_Tian_S1_SIFT2_FBC_i2',
'Schaefer7n200p_Tian_S1_Streamline_Count_i2',

'Schaefer7n1000p_Tian_S4_FA_i2',
'Schaefer7n1000p_Tian_S4_Length_i2',
'Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2',
'Schaefer7n1000p_Tian_S4_Streamline_Count_i2',

"amplitudes_21",
"full_correlation_21",
"partial_correlation_21",
"amplitudes_55",
"full_correlation_55",
"partial_correlation_55",
'full_correlation_aparc_a2009s_Tian_S1',
'full_correlation_aparc_Tian_S1',
'full_correlation_Glasser_Tian_S1',
'full_correlation_Glasser_Tian_S4',
'full_correlation_Schaefer7n200p_Tian_S1',
'full_correlation_Schaefer7n500p_Tian_S4',
'partial_correlation_aparc_a2009s_Tian_S1',
'partial_correlation_aparc_Tian_S1',
'partial_correlation_Glasser_Tian_S1',
'partial_correlation_Glasser_Tian_S4',
'partial_correlation_Schaefer7n200p_Tian_S1',
'partial_correlation_Schaefer7n500p_Tian_S4'
]

modalities_body = [
'immune',
'renalhepatic',
'metabolic',
'cardiopulmonary',
'musculoskeletal',
'bone_densitometry',
'pwa',
'heart_mri',
'carotid_ultrasound',
'arterial_stiffness',
'ecg_rest',
'body_composition_by_impedance',
'body_composition_dxa',
'bone_dxa',
'kidneys_mri',
'liver_mri',
'abdominal_composition_mri_18_vars', #17 vars
'abdominal_organ_composition_mri_13_vars', #12 vars
'hearing'
]

# %%
# Match features and targets
base_path = '/UK_BB/brainbody'
folds = range(0, 5)
warnings.simplefilter(action='ignore', category=FutureWarning)

for fold in folds:
    print(f'Started {fold}', flush=True)
    all_modalities_train = []
    all_modalities_test = []
    
    # Define paths with proper formatting
    paths = {
        'body': {
            'train': os.path.join(base_path, 'lifestyle-envir-body', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
            'test': os.path.join(base_path, 'lifestyle-envir-body', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
        },
        'brain': {
            'train': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_train_with_id_fold_{}.csv'),
            'test': os.path.join(base_path, 'brain', 'folds', 'fold_{}', 'g_pred', '{}_g_pred_XGB_test_with_id_fold_{}.csv')
        },
        'g_observed': {
            'train': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_train_with_id_{}.csv'),
            'test': os.path.join(base_path, 'cognition', 'folds', 'fold_{}', 'g', 'g_test_with_id_{}.csv')
        },
        'stacking_output': {
            'train': os.path.join(base_path, 'stacking', 'brain-body'),
            'test': os.path.join(base_path, 'stacking', 'brain-body')
        }
    }

    # Create output directories
    for path_type in ['train', 'test']:
        os.makedirs(os.path.join(paths['stacking_output'][path_type], 'features_train_level1_stacked_inner'), exist_ok=True)
        os.makedirs(os.path.join(paths['stacking_output'][path_type], 'features_test_level1_stacked_inner'), exist_ok=True)
        os.makedirs(os.path.join(paths['stacking_output'][path_type], 'features_train_level1_stacked_outer'), exist_ok=True)
        os.makedirs(os.path.join(paths['stacking_output'][path_type], 'features_test_level1_stacked_outer'), exist_ok=True)

    for modality in modalities_brain_body:
        # Get correct paths based on modality type
        modality_type = 'body' if modality in modalities_body else 'brain'
        train_path = paths[modality_type]['train'].format(fold, modality, fold)
        test_path = paths[modality_type]['test'].format(fold, modality, fold)
        
        # Load data if paths exist
        if os.path.exists(train_path):
            train_df = pd.read_csv(train_path)
            all_modalities_train.append(train_df)
        
        if os.path.exists(test_path):
            test_df = pd.read_csv(test_path)
            all_modalities_test.append(test_df)
    
    # Merge all modalities - INNER VERSION
    def merge_modalities_inner(df_list):
        if not df_list:
            return pd.DataFrame()
        merged = df_list[0]
        for df in df_list[1:]:
            merged = pd.merge(merged, df, on='eid', how='inner')
        return merged
    
    # Merge all modalities - OUTER VERSION (your existing function)
    def merge_modalities_outer(df_list):
        if not df_list:
            return pd.DataFrame()
        merged = df_list[0]
        for df in df_list[1:]:
            merged = pd.merge(merged, df, on='eid', how='outer')
        return merged
    
    # Process train data - BOTH MERGE TYPES
    if all_modalities_train:
        g_observed_train = pd.read_csv(paths['g_observed']['train'].format(fold, fold))
        
        # Inner merge
        features_train_inner = merge_modalities_inner(all_modalities_train)
        features_train_inner.to_csv(
            os.path.join(paths['stacking_output']['train'], 'features_train_level1_stacked_inner', f'features_train_level1_inner_fold_{fold}.csv'), 
            index=False
        )
        pd.merge(features_train_inner, g_observed_train, on='eid', how='inner').to_csv(
            os.path.join(paths['stacking_output']['train'], 'features_train_level1_stacked_inner', f'features_train_level1_inner_g_matched_fold_{fold}.csv'),
            index=False
        )
        
        # Outer merge (your existing code)
        features_train_outer = merge_modalities_outer(all_modalities_train)
        features_train_outer.to_csv(
            os.path.join(paths['stacking_output']['train'], 'features_train_level1_stacked_outer', f'features_train_level1_outer_fold_{fold}.csv'), 
            index=False
        )
        pd.merge(features_train_outer, g_observed_train, on='eid', how='left').to_csv(
            os.path.join(paths['stacking_output']['train'], 'features_train_level1_stacked_outer', f'features_train_level1_outer_g_matched_fold_{fold}.csv'),
            index=False
        )
    
    # Process test data - BOTH MERGE TYPES
    if all_modalities_test:
        g_observed_test = pd.read_csv(paths['g_observed']['test'].format(fold, fold))
        
        # Inner merge
        features_test_inner = merge_modalities_inner(all_modalities_test)
        features_test_inner.to_csv(
            os.path.join(paths['stacking_output']['test'], 'features_test_level1_stacked_inner', f'features_test_level1_inner_fold_{fold}.csv'), 
            index=False
        )
        pd.merge(features_test_inner, g_observed_test, on='eid', how='inner').to_csv(
            os.path.join(paths['stacking_output']['test'], 'features_test_level1_stacked_inner', f'features_test_level1_inner_g_matched_fold_{fold}.csv'),
            index=False
        )
        
        # Outer merge (your existing code)
        features_test_outer = merge_modalities_outer(all_modalities_test)
        features_test_outer.to_csv(
            os.path.join(paths['stacking_output']['test'], 'features_test_level1_stacked_outer', f'features_test_level1_outer_fold_{fold}.csv'), 
            index=False
        )
        pd.merge(features_test_outer, g_observed_test, on='eid', how='left').to_csv(
            os.path.join(paths['stacking_output']['test'], 'features_test_level1_stacked_outer', f'features_test_level1_outer_g_matched_fold_{fold}.csv'),
            index=False
        )

# %%
# Analyze all folds
paths = {
    'stacking_output': {
        'train_stacked_inner': os.path.join(base_path, 'stacking', 'brain-body', 'features_train_level1_stacked_inner', 'features_train_level1_inner_fold_{}.csv'),
        'train_stacked_outer': os.path.join(base_path, 'stacking', 'brain-body', 'features_train_level1_stacked_outer', 'features_train_level1_outer_fold_{}.csv'),
        'train_g_matched_inner': os.path.join(base_path, 'stacking', 'brain-body','features_train_level1_stacked_inner', 'features_train_level1_inner_g_matched_fold_{}.csv'),
        'train_g_matched_outer': os.path.join(base_path, 'stacking', 'brain-body', 'features_train_level1_stacked_outer', 'features_train_level1_outer_g_matched_fold_{}.csv'),
        'test_stacked_inner': os.path.join(base_path, 'stacking', 'brain-body', 'features_test_level1_stacked_inner', 'features_test_inner_level1_fold_{}.csv'),
        'test_stacked_outer': os.path.join(base_path, 'stacking', 'brain-body', 'features_test_level1_stacked_outer', 'features_test_level1_outer_fold_{}.csv'),
        'test_g_matched_inner': os.path.join(base_path, 'stacking', 'brain-body', 'features_test_level1_stacked_inner', 'features_test_level1_inner_g_matched_fold_{}.csv'),
        'test_g_matched_outer': os.path.join(base_path, 'stacking', 'brain-body', 'features_test_level1_stacked_outer', 'features_test_level1_outer_g_matched_fold_{}.csv')
    }
}

results = [analyze_g_matched(fold, paths) for fold in folds]
results_df = pd.DataFrame(results)
all_features_consistent = all(
    set(r['ncols Train']) == set(results[0]['ncols Train']) 
    for r in results)

print("Sample Sizes and Feature Counts:")
results_df[['Fold', 'N Train Inner', 'N Test Inner', 'N Train Outer', 'N Test Outer', 'N Features']]
# Out:
# Sample Sizes and Feature Counts:
#    Fold  N Train Inner  N Test Inner  N Train Outer  N Test Outer  N Features
# 0     0            949           289          25517          6380         100
# 1     1           1002           236          25517          6380         100
# 2     2           1007           231          25518          6379         100
# 3     3            996           242          25518          6379         100
# 4     4            998           240          25518          6379         100
