# %%
import csv
import os
import random
import pickle
import gc
import xgboost as xgb
import pandas as pd
import numpy as np
from scipy import stats
import sklearn
import warnings
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Stacking

# %% [markdown]
# ## Body

# %%
# OUTER STACK (PC version) RandomForest ensemble
# Configuration
algorithms = ['rf'] 
folds = range(5)  # Changed from strings to integers 0-4
modality_name = 'body'
seed = 10

base_path = '/UK_BB/brainbody'  
stacking_path = os.path.join(base_path, 'stacking', modality_name)
cognition_path = os.path.join(base_path, 'cognition')
merge_type = 'outer'

# Main processing loop
for fold in folds:
    print(f"\n{'='*50}")
    print(f"Processing fold {fold}")
    print(f"{'='*50}")
    
    # Create fold-specific paths
    folds_path = os.path.join(stacking_path, 'folds', f'fold_{fold}')
    suppl_path = os.path.join(folds_path, 'suppl')
    scaling_path = os.path.join(folds_path, 'scaling')
    models_path = os.path.join(folds_path, 'models')
    g_pred_path = os.path.join(folds_path, 'g_pred')

    # Create directories
    for path in [folds_path, suppl_path, scaling_path, models_path, g_pred_path]:
        os.makedirs(path, exist_ok=True)

    def load_data(fold, data_type):
        """Load pre-matched features and target data."""
        if data_type == 'train':
            data_path = os.path.join(stacking_path, 'features_train_level1_stacked_outer', 
                                   f'features_train_level1_outer_g_matched_fold_{fold}.csv')
        elif data_type == 'test':
            data_path = os.path.join(stacking_path, 'features_test_level1_stacked_outer',
                                   f'features_test_level1_outer_g_matched_fold_{fold}.csv')
        
        if not os.path.exists(data_path):
            raise FileNotFoundError(f"Data file not found at: {data_path}")
        
        df = pd.read_csv(data_path)
        print(f"\nLoading {data_type} data for fold {fold} from: {data_path}")
        print(f"Columns: {df.columns.tolist()}")
        print(f"Shape: {df.shape}")
        
        target_values = df['g'].values.reshape(-1, 1)
        target_ids = df['eid']
        features = df.drop(columns=['eid', 'g'])
        features.columns = features.columns.str.replace(f'_{data_type}_', '')
        
        return features, target_values, target_ids

    # Load train and test data
    features_train, target_real_train, target_real_train_id = load_data(fold, 'train')
    features_test, target_real_test, target_real_test_id = load_data(fold, 'test')

    # Scaling
    scaler_features = StandardScaler()
    scaler_target = StandardScaler()

    target_real_train = scaler_target.fit_transform(target_real_train)
    target_real_test = scaler_target.transform(target_real_test)

    features_train = scaler_features.fit_transform(features_train)
    features_test = scaler_features.transform(features_test)

    for algorithm in range(len(algorithms)):
        algorithm_performance = {}

        if algorithms[algorithm] == 'xgb':
            param = {
                'booster': ['gbtree'],
                'eta': [0.01, 0.05, 0.1],
                'max_depth': [1, 2, 3],
                'subsample': [0.8, 1],
                'reg_lambda': [0, 0.1, 0.5],
                'reg_alpha': [0, 0.01, 0.1],
                'min_child_weight': [1, 3],
                'colsample_bytree': [0.6, 0.8],
                'gamma': [0, 0.1]
            }
            regressor = xgb.XGBRegressor(
                random_state=seed,
                objective='reg:squarederror',
            )
         
        elif algorithms[algorithm] == 'rf':
            print('Started RF')
            param = {
                'n_estimators': [5000],
                'max_depth': [1, 2, 3, 4, 5, 6],
                'max_features': ['sqrt', 'log2']
            }
            regressor = RandomForestRegressor(random_state=seed)

        model = GridSearchCV(regressor, param, cv=5, verbose=4, n_jobs=-1)  # n_jobs=-1 uses all cores
        model.fit(features_train, target_real_train.ravel())

        # Save model
        with open(os.path.join(models_path, f'{modality_name}_stacked_{algorithm}_{merge_type}_model_fold_{fold}.pkl'), 'wb') as f:
            pickle.dump(model, f)

        # Predictions
        target_pred_train = model.predict(features_train)
        target_pred_test = model.predict(features_test)

        # Save predictions
        pd.DataFrame({'eid': target_real_train_id, 'g_pred_stack_train': target_pred_train}).to_csv(
            os.path.join(g_pred_path, f'{modality_name}_target_pred_2nd_level_{algorithm}_{merge_type}_train_fold_{fold}.csv'),
            index=False
        )

        pd.DataFrame({'eid': target_real_test_id, 'g_pred_stack_test': target_pred_test}).to_csv(
            os.path.join(g_pred_path, f'{modality_name}_target_pred_2nd_level_{algorithm}_{merge_type}_test_fold_{fold}.csv'),
            index=False
        )

        # Store results
        algorithm_performance = {
            'Algorithm': algorithms[algorithm],
            'Fold': fold,
            'Best_params': str(model.best_params_),
            'Test_MSE': mean_squared_error(target_real_test, target_pred_test),
            'Test_MAE': mean_absolute_error(target_real_test, target_pred_test),
            'Test_R2': r2_score(target_real_test, target_pred_test),
            'Test_Pearson_r': pearsonr(target_real_test.squeeze(), target_pred_test.squeeze())[0],
            'Train_MSE': mean_squared_error(target_real_train, target_pred_train),
            'Train_MAE': mean_absolute_error(target_real_train, target_pred_train),
            'Train_R2': r2_score(target_real_train, target_pred_train),
            'Train_Pearson_r': pearsonr(target_real_train.squeeze(), target_pred_train.squeeze())[0]
        }

        # Write results
        results_file = os.path.join(models_path, f'{modality_name}_{algorithm}_{merge_type}_stacked_result_fold_{fold}.csv')
        with open(results_file, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=algorithm_performance.keys())
            writer.writeheader()
            writer.writerow(algorithm_performance)

print("\nAll folds processed successfully!")

# %% [markdown]
# ## Body + brain

# %%
# OUTER STACK (PC version) RandomForest ensemble
# Configuration
algorithms = ['rf']
folds = range(5)
modality_name = 'brain-body'
seed = 10

base_path = '/UK_BB/brainbody'  
stacking_path = os.path.join(base_path, 'stacking', modality_name)
cognition_path = os.path.join(base_path, 'cognition')
merge_type = 'outer'

# Main processing loop
for fold in folds:
    print(f"\n{'='*50}")
    print(f"Processing fold {fold}")
    print(f"{'='*50}")
    
    # Create fold-specific paths
    folds_path = os.path.join(stacking_path, 'folds', f'fold_{fold}')
    suppl_path = os.path.join(folds_path, 'suppl')
    scaling_path = os.path.join(folds_path, 'scaling')
    models_path = os.path.join(folds_path, 'models')
    g_pred_path = os.path.join(folds_path, 'g_pred')

    # Create directories
    for path in [folds_path, suppl_path, scaling_path, models_path, g_pred_path]:
        os.makedirs(path, exist_ok=True)

    def load_data(fold, data_type):
        """Load pre-matched features and target data."""
        if data_type == 'train':
            data_path = os.path.join(stacking_path, 'features_train_level1_stacked_outer', 
                                   f'features_train_level1_outer_g_matched_fold_{fold}.csv')
        elif data_type == 'test':
            data_path = os.path.join(stacking_path, 'features_test_level1_stacked_outer',
                                   f'features_test_level1_outer_g_matched_fold_{fold}.csv')
        
        if not os.path.exists(data_path):
            raise FileNotFoundError(f"Data file not found at: {data_path}")
        
        df = pd.read_csv(data_path)
        print(f"\nLoading {data_type} data for fold {fold} from: {data_path}")
        print(f"Columns: {df.columns.tolist()}")
        print(f"Shape: {df.shape}")
        
        target_values = df['g'].values.reshape(-1, 1)
        target_ids = df['eid']
        features = df.drop(columns=['eid', 'g'])
        features.columns = features.columns.str.replace(f'_{data_type}_', '')
        
        return features, target_values, target_ids

    # Load train and test data
    features_train, target_real_train, target_real_train_id = load_data(fold, 'train')
    features_test, target_real_test, target_real_test_id = load_data(fold, 'test')

    # Scaling
    scaler_features = StandardScaler()
    scaler_target = StandardScaler()

    target_real_train = scaler_target.fit_transform(target_real_train)
    target_real_test = scaler_target.transform(target_real_test)

    features_train = scaler_features.fit_transform(features_train)
    features_test = scaler_features.transform(features_test)

    for algorithm in range(len(algorithms)):
        algorithm_performance = {}

        if algorithms[algorithm] == 'xgb':
            param = {
                'booster': ['gbtree'],
                'eta': [0.01, 0.05, 0.1],
                'max_depth': [1, 2, 3],
                'subsample': [0.8, 1],
                'reg_lambda': [0, 0.1, 0.5],
                'reg_alpha': [0, 0.01, 0.1],
                'min_child_weight': [1, 3],
                'colsample_bytree': [0.6, 0.8],
                'gamma': [0, 0.1]
            }
            regressor = xgb.XGBRegressor(
                random_state=seed,
                objective='reg:squarederror',
            )
         
        elif algorithms[algorithm] == 'rf':
            print('Started RF')
            param = {
                'n_estimators': [5000],
                'max_depth': [1, 2, 3, 4, 5, 6],
                'max_features': ['sqrt', 'log2']
            }
            regressor = RandomForestRegressor(random_state=seed)

        model = GridSearchCV(regressor, param, cv=5, verbose=4, n_jobs=-1)  # n_jobs=-1 uses all cores
        model.fit(features_train, target_real_train.ravel())

        # Save model
        with open(os.path.join(models_path, f'{modality_name}_stacked_{algorithm}_{merge_type}_model_fold_{fold}.pkl'), 'wb') as f:
            pickle.dump(model, f)

        # Predictions
        target_pred_train = model.predict(features_train)
        target_pred_test = model.predict(features_test)

        # Save predictions
        pd.DataFrame({'eid': target_real_train_id, 'g_pred_stack_train': target_pred_train}).to_csv(
            os.path.join(g_pred_path, f'{modality_name}_target_pred_2nd_level_{algorithm}_{merge_type}_train_fold_{fold}.csv'),
            index=False
        )

        pd.DataFrame({'eid': target_real_test_id, 'g_pred_stack_test': target_pred_test}).to_csv(
            os.path.join(g_pred_path, f'{modality_name}_target_pred_2nd_level_{algorithm}_{merge_type}_test_fold_{fold}.csv'),
            index=False
        )

        # Store results
        algorithm_performance = {
            'Algorithm': algorithms[algorithm],
            'Fold': fold,
            'Best_params': str(model.best_params_),
            'Test_MSE': mean_squared_error(target_real_test, target_pred_test),
            'Test_MAE': mean_absolute_error(target_real_test, target_pred_test),
            'Test_R2': r2_score(target_real_test, target_pred_test),
            'Test_Pearson_r': pearsonr(target_real_test.squeeze(), target_pred_test.squeeze())[0],
            'Train_MSE': mean_squared_error(target_real_train, target_pred_train),
            'Train_MAE': mean_absolute_error(target_real_train, target_pred_train),
            'Train_R2': r2_score(target_real_train, target_pred_train),
            'Train_Pearson_r': pearsonr(target_real_train.squeeze(), target_pred_train.squeeze())[0]
        }

        # Write results
        results_file = os.path.join(models_path, f'{modality_name}_{algorithm}_{merge_type}_stacked_result_fold_{fold}.csv')
        with open(results_file, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=algorithm_performance.keys())
            writer.writeheader()
            writer.writerow(algorithm_performance)

print("\nAll folds processed successfully!")
# Out:
# ==================================================
# Processing fold 0
# ==================================================
#
# Loading train data for fold 0 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_train_level1_stacked_outer/features_train_level1_outer_g_matched_fold_0.csv
# Columns: ['eid', 'g_pred_train_immune', 'g_pred_train_renalhepatic', 'g_pred_train_metabolic', 'g_pred_train_cardiopulmonary', 'g_pred_train_musculoskeletal', 'g_pred_train_bone_densitometry', 'g_pred_train_pwa', 'g_pred_train_heart_mri', 'g_pred_train_carotid_ultrasound', 'g_pred_train_arterial_stiffness', 'g_pred_train_ecg_rest', 'g_pred_train_body_composition_by_impedance', 'g_pred_train_body_composition_dxa', 'g_pred_train_bone_dxa', 'g_pred_train_kidneys_mri', 'g_pred_train_liver_mri', 'g_pred_train_abdominal_composition_mri_18_vars', 'g_pred_train_abdominal_organ_composition_mri_13_vars', 'g_pred_train_hearing', 'g_pred_train_struct_fast', 'g_pred_train_struct_sub_first', 'g_pred_train_struct_fs_aseg_mean_intensity', 'g_pred_train_struct_fs_aseg_volume', 'g_pred_train_struct_ba_exvivo_area', 'g_pred_train_struct_ba_exvivo_mean_thickness', 'g_pred_train_struct_ba_exvivo_volume', 'g_pred_train_struct_a2009s_area', 'g_pred_train_struct_a2009s_mean_thickness', 'g_pred_train_struct_a2009s_volume', 'g_pred_train_struct_dkt_area', 'g_pred_train_struct_dkt_mean_thickness', 'g_pred_train_struct_dkt_volume', 'g_pred_train_struct_desikan_gw', 'g_pred_train_struct_desikan_pial', 'g_pred_train_struct_desikan_white_area', 'g_pred_train_struct_desikan_white_mean_thickness', 'g_pred_train_struct_desikan_white_volume', 'g_pred_train_struct_subsegmentation', 'g_pred_train_add_t1', 'g_pred_train_add_t2', 'g_pred_train_dwi_FA_tbss', 'g_pred_train_dwi_FA_prob', 'g_pred_train_dwi_MD_tbss', 'g_pred_train_dwi_MD_prob', 'g_pred_train_dwi_L1_tbss', 'g_pred_train_dwi_L1_prob', 'g_pred_train_dwi_L2_tbss', 'g_pred_train_dwi_L2_prob', 'g_pred_train_dwi_L3_tbss', 'g_pred_train_dwi_L3_prob', 'g_pred_train_dwi_MO_tbss', 'g_pred_train_dwi_MO_prob', 'g_pred_train_dwi_OD_tbss', 'g_pred_train_dwi_OD_prob', 'g_pred_train_dwi_ICVF_tbss', 'g_pred_train_dwi_ICVF_prob', 'g_pred_train_dwi_ISOVF_tbss', 'g_pred_train_dwi_ISOVF_prob', 'g_pred_train_aparc_Tian_S1_FA_i2', 'g_pred_train_aparc_Tian_S1_Length_i2', 'g_pred_train_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_train_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_train_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S1_FA_i2', 'g_pred_train_Glasser_Tian_S1_Length_i2', 'g_pred_train_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S4_FA_i2', 'g_pred_train_Glasser_Tian_S4_Length_i2', 'g_pred_train_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_train_amplitudes_21', 'g_pred_train_full_correlation_21', 'g_pred_train_partial_correlation_21', 'g_pred_train_amplitudes_55', 'g_pred_train_full_correlation_55', 'g_pred_train_partial_correlation_55', 'g_pred_train_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_full_correlation_aparc_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S4', 'g_pred_train_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_train_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_partial_correlation_aparc_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S4', 'g_pred_train_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (25517, 102)
#
# Loading test data for fold 0 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_test_level1_stacked_outer/features_test_level1_outer_g_matched_fold_0.csv
# Columns: ['eid', 'g_pred_test_immune', 'g_pred_test_renalhepatic', 'g_pred_test_metabolic', 'g_pred_test_cardiopulmonary', 'g_pred_test_musculoskeletal', 'g_pred_test_bone_densitometry', 'g_pred_test_pwa', 'g_pred_test_heart_mri', 'g_pred_test_carotid_ultrasound', 'g_pred_test_arterial_stiffness', 'g_pred_test_ecg_rest', 'g_pred_test_body_composition_by_impedance', 'g_pred_test_body_composition_dxa', 'g_pred_test_bone_dxa', 'g_pred_test_kidneys_mri', 'g_pred_test_liver_mri', 'g_pred_test_abdominal_composition_mri_18_vars', 'g_pred_test_abdominal_organ_composition_mri_13_vars', 'g_pred_test_hearing', 'g_pred_test_struct_fast', 'g_pred_test_struct_sub_first', 'g_pred_test_struct_fs_aseg_mean_intensity', 'g_pred_test_struct_fs_aseg_volume', 'g_pred_test_struct_ba_exvivo_area', 'g_pred_test_struct_ba_exvivo_mean_thickness', 'g_pred_test_struct_ba_exvivo_volume', 'g_pred_test_struct_a2009s_area', 'g_pred_test_struct_a2009s_mean_thickness', 'g_pred_test_struct_a2009s_volume', 'g_pred_test_struct_dkt_area', 'g_pred_test_struct_dkt_mean_thickness', 'g_pred_test_struct_dkt_volume', 'g_pred_test_struct_desikan_gw', 'g_pred_test_struct_desikan_pial', 'g_pred_test_struct_desikan_white_area', 'g_pred_test_struct_desikan_white_mean_thickness', 'g_pred_test_struct_desikan_white_volume', 'g_pred_test_struct_subsegmentation', 'g_pred_test_add_t1', 'g_pred_test_add_t2', 'g_pred_test_dwi_FA_tbss', 'g_pred_test_dwi_FA_prob', 'g_pred_test_dwi_MD_tbss', 'g_pred_test_dwi_MD_prob', 'g_pred_test_dwi_L1_tbss', 'g_pred_test_dwi_L1_prob', 'g_pred_test_dwi_L2_tbss', 'g_pred_test_dwi_L2_prob', 'g_pred_test_dwi_L3_tbss', 'g_pred_test_dwi_L3_prob', 'g_pred_test_dwi_MO_tbss', 'g_pred_test_dwi_MO_prob', 'g_pred_test_dwi_OD_tbss', 'g_pred_test_dwi_OD_prob', 'g_pred_test_dwi_ICVF_tbss', 'g_pred_test_dwi_ICVF_prob', 'g_pred_test_dwi_ISOVF_tbss', 'g_pred_test_dwi_ISOVF_prob', 'g_pred_test_aparc_Tian_S1_FA_i2', 'g_pred_test_aparc_Tian_S1_Length_i2', 'g_pred_test_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_test_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_test_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S1_FA_i2', 'g_pred_test_Glasser_Tian_S1_Length_i2', 'g_pred_test_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S4_FA_i2', 'g_pred_test_Glasser_Tian_S4_Length_i2', 'g_pred_test_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_test_amplitudes_21', 'g_pred_test_full_correlation_21', 'g_pred_test_partial_correlation_21', 'g_pred_test_amplitudes_55', 'g_pred_test_full_correlation_55', 'g_pred_test_partial_correlation_55', 'g_pred_test_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_full_correlation_aparc_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S4', 'g_pred_test_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_test_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_partial_correlation_aparc_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S4', 'g_pred_test_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (6380, 102)
# Started RF
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 4/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.336 total time= 1.5min
# [CV 5/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.336 total time= 1.5min
# [CV 1/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.335 total time= 1.5min
# [CV 2/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.330 total time= 1.5min
# [CV 3/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.332 total time= 1.5min
# [CV 4/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.370 total time= 2.3min
# [CV 1/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.370 total time= 2.4min
# [CV 3/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.367 total time= 2.4min
# [CV 5/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.372 total time= 2.4min
# [CV 2/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.364 total time= 2.4min
# [CV 3/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.510 total time= 2.6min
# [CV 1/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.508 total time= 2.7min
# [CV 4/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.504 total time= 2.7min
# [CV 2/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.509 total time= 2.7min
# [CV 5/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.510 total time= 2.7min
# [CV 3/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.582 total time= 3.6min
# [CV 2/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.583 total time= 3.6min
# [CV 1/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.579 total time= 3.6min
# [CV 5/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.582 total time= 3.6min
# [CV 4/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.573 total time= 3.7min
# [CV 1/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.550 total time= 4.1min
# [CV 3/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.553 total time= 4.1min
# [CV 4/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.548 total time= 4.1min
# [CV 5/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.554 total time= 4.1min
# [CV 2/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.552 total time= 4.2min
# [CV 4/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.618 total time= 4.4min
# [CV 2/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.630 total time= 4.4min
# [CV 5/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.627 total time= 4.5min
# [CV 1/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.626 total time= 4.5min
# [CV 3/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.628 total time= 4.6min
# [CV 3/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.660 total time= 5.1min
# [CV 5/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.659 total time= 5.1min
# [CV 4/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.649 total time= 5.1min
# [CV 1/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.659 total time= 5.1min
# [CV 2/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.662 total time= 5.2min
# [CV 4/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.612 total time= 5.3min
# [CV 1/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.616 total time= 5.4min
# [CV 2/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.621 total time= 5.4min
# [CV 5/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.620 total time= 5.5min
# [CV 3/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.622 total time= 5.5min
# [CV 5/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.685 total time= 5.6min
# [CV 3/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.685 total time= 5.7min
# [CV 4/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.675 total time= 5.8min
# [CV 1/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.686 total time= 5.8min
# [CV 2/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.688 total time= 5.9min
# [CV 3/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.663 total time= 6.5min
# [CV 2/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.664 total time= 6.5min
# [CV 4/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.653 total time= 6.6min
# [CV 5/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.661 total time= 6.6min
# [CV 1/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.659 total time= 6.6min
# [CV 4/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.682 total time= 7.5min
# [CV 1/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.690 total time= 7.5min
# [CV 2/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.693 total time= 7.6min
# [CV 3/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.692 total time= 7.6min
# [CV 5/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.691 total time= 7.9min
# [CV 4/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.704 total time= 8.4min
# [CV 2/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.716 total time= 8.4min
# [CV 1/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.714 total time= 8.4min
# [CV 5/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.713 total time= 8.4min
# [CV 3/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.714 total time= 8.5min
#
# ==================================================
# Processing fold 1
# ==================================================
#
# Loading train data for fold 1 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_train_level1_stacked_outer/features_train_level1_outer_g_matched_fold_1.csv
# Columns: ['eid', 'g_pred_train_immune', 'g_pred_train_renalhepatic', 'g_pred_train_metabolic', 'g_pred_train_cardiopulmonary', 'g_pred_train_musculoskeletal', 'g_pred_train_bone_densitometry', 'g_pred_train_pwa', 'g_pred_train_heart_mri', 'g_pred_train_carotid_ultrasound', 'g_pred_train_arterial_stiffness', 'g_pred_train_ecg_rest', 'g_pred_train_body_composition_by_impedance', 'g_pred_train_body_composition_dxa', 'g_pred_train_bone_dxa', 'g_pred_train_kidneys_mri', 'g_pred_train_liver_mri', 'g_pred_train_abdominal_composition_mri_18_vars', 'g_pred_train_abdominal_organ_composition_mri_13_vars', 'g_pred_train_hearing', 'g_pred_train_struct_fast', 'g_pred_train_struct_sub_first', 'g_pred_train_struct_fs_aseg_mean_intensity', 'g_pred_train_struct_fs_aseg_volume', 'g_pred_train_struct_ba_exvivo_area', 'g_pred_train_struct_ba_exvivo_mean_thickness', 'g_pred_train_struct_ba_exvivo_volume', 'g_pred_train_struct_a2009s_area', 'g_pred_train_struct_a2009s_mean_thickness', 'g_pred_train_struct_a2009s_volume', 'g_pred_train_struct_dkt_area', 'g_pred_train_struct_dkt_mean_thickness', 'g_pred_train_struct_dkt_volume', 'g_pred_train_struct_desikan_gw', 'g_pred_train_struct_desikan_pial', 'g_pred_train_struct_desikan_white_area', 'g_pred_train_struct_desikan_white_mean_thickness', 'g_pred_train_struct_desikan_white_volume', 'g_pred_train_struct_subsegmentation', 'g_pred_train_add_t1', 'g_pred_train_add_t2', 'g_pred_train_dwi_FA_tbss', 'g_pred_train_dwi_FA_prob', 'g_pred_train_dwi_MD_tbss', 'g_pred_train_dwi_MD_prob', 'g_pred_train_dwi_L1_tbss', 'g_pred_train_dwi_L1_prob', 'g_pred_train_dwi_L2_tbss', 'g_pred_train_dwi_L2_prob', 'g_pred_train_dwi_L3_tbss', 'g_pred_train_dwi_L3_prob', 'g_pred_train_dwi_MO_tbss', 'g_pred_train_dwi_MO_prob', 'g_pred_train_dwi_OD_tbss', 'g_pred_train_dwi_OD_prob', 'g_pred_train_dwi_ICVF_tbss', 'g_pred_train_dwi_ICVF_prob', 'g_pred_train_dwi_ISOVF_tbss', 'g_pred_train_dwi_ISOVF_prob', 'g_pred_train_aparc_Tian_S1_FA_i2', 'g_pred_train_aparc_Tian_S1_Length_i2', 'g_pred_train_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_train_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_train_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S1_FA_i2', 'g_pred_train_Glasser_Tian_S1_Length_i2', 'g_pred_train_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S4_FA_i2', 'g_pred_train_Glasser_Tian_S4_Length_i2', 'g_pred_train_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_train_amplitudes_21', 'g_pred_train_full_correlation_21', 'g_pred_train_partial_correlation_21', 'g_pred_train_amplitudes_55', 'g_pred_train_full_correlation_55', 'g_pred_train_partial_correlation_55', 'g_pred_train_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_full_correlation_aparc_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S4', 'g_pred_train_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_train_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_partial_correlation_aparc_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S4', 'g_pred_train_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (25517, 102)
#
# Loading test data for fold 1 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_test_level1_stacked_outer/features_test_level1_outer_g_matched_fold_1.csv
# Columns: ['eid', 'g_pred_test_immune', 'g_pred_test_renalhepatic', 'g_pred_test_metabolic', 'g_pred_test_cardiopulmonary', 'g_pred_test_musculoskeletal', 'g_pred_test_bone_densitometry', 'g_pred_test_pwa', 'g_pred_test_heart_mri', 'g_pred_test_carotid_ultrasound', 'g_pred_test_arterial_stiffness', 'g_pred_test_ecg_rest', 'g_pred_test_body_composition_by_impedance', 'g_pred_test_body_composition_dxa', 'g_pred_test_bone_dxa', 'g_pred_test_kidneys_mri', 'g_pred_test_liver_mri', 'g_pred_test_abdominal_composition_mri_18_vars', 'g_pred_test_abdominal_organ_composition_mri_13_vars', 'g_pred_test_hearing', 'g_pred_test_struct_fast', 'g_pred_test_struct_sub_first', 'g_pred_test_struct_fs_aseg_mean_intensity', 'g_pred_test_struct_fs_aseg_volume', 'g_pred_test_struct_ba_exvivo_area', 'g_pred_test_struct_ba_exvivo_mean_thickness', 'g_pred_test_struct_ba_exvivo_volume', 'g_pred_test_struct_a2009s_area', 'g_pred_test_struct_a2009s_mean_thickness', 'g_pred_test_struct_a2009s_volume', 'g_pred_test_struct_dkt_area', 'g_pred_test_struct_dkt_mean_thickness', 'g_pred_test_struct_dkt_volume', 'g_pred_test_struct_desikan_gw', 'g_pred_test_struct_desikan_pial', 'g_pred_test_struct_desikan_white_area', 'g_pred_test_struct_desikan_white_mean_thickness', 'g_pred_test_struct_desikan_white_volume', 'g_pred_test_struct_subsegmentation', 'g_pred_test_add_t1', 'g_pred_test_add_t2', 'g_pred_test_dwi_FA_tbss', 'g_pred_test_dwi_FA_prob', 'g_pred_test_dwi_MD_tbss', 'g_pred_test_dwi_MD_prob', 'g_pred_test_dwi_L1_tbss', 'g_pred_test_dwi_L1_prob', 'g_pred_test_dwi_L2_tbss', 'g_pred_test_dwi_L2_prob', 'g_pred_test_dwi_L3_tbss', 'g_pred_test_dwi_L3_prob', 'g_pred_test_dwi_MO_tbss', 'g_pred_test_dwi_MO_prob', 'g_pred_test_dwi_OD_tbss', 'g_pred_test_dwi_OD_prob', 'g_pred_test_dwi_ICVF_tbss', 'g_pred_test_dwi_ICVF_prob', 'g_pred_test_dwi_ISOVF_tbss', 'g_pred_test_dwi_ISOVF_prob', 'g_pred_test_aparc_Tian_S1_FA_i2', 'g_pred_test_aparc_Tian_S1_Length_i2', 'g_pred_test_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_test_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_test_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S1_FA_i2', 'g_pred_test_Glasser_Tian_S1_Length_i2', 'g_pred_test_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S4_FA_i2', 'g_pred_test_Glasser_Tian_S4_Length_i2', 'g_pred_test_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_test_amplitudes_21', 'g_pred_test_full_correlation_21', 'g_pred_test_partial_correlation_21', 'g_pred_test_amplitudes_55', 'g_pred_test_full_correlation_55', 'g_pred_test_partial_correlation_55', 'g_pred_test_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_full_correlation_aparc_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S4', 'g_pred_test_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_test_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_partial_correlation_aparc_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S4', 'g_pred_test_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (6380, 102)
# Started RF
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 4/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.344 total time= 1.5min
# [CV 5/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.353 total time= 1.5min
# [CV 3/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.339 total time= 1.5min
# [CV 1/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.353 total time= 1.5min
# [CV 2/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.346 total time= 1.5min
# [CV 1/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.391 total time= 2.4min
# [CV 5/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.393 total time= 2.4min
# [CV 3/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.378 total time= 2.4min
# [CV 4/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.382 total time= 2.4min
# [CV 2/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.386 total time= 2.4min
# [CV 1/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.524 total time= 2.7min
# [CV 4/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.521 total time= 2.7min
# [CV 2/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.524 total time= 2.8min
# [CV 5/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.533 total time= 2.8min
# [CV 3/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.524 total time= 2.8min
# [CV 2/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.596 total time= 3.7min
# [CV 5/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.606 total time= 3.7min
# [CV 3/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.598 total time= 3.7min
# [CV 4/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.591 total time= 3.7min
# [CV 1/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.592 total time= 3.8min
# [CV 5/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.580 total time= 4.2min
# [CV 1/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.568 total time= 4.2min
# [CV 3/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.571 total time= 4.2min
# [CV 4/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.568 total time= 4.3min
# [CV 2/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.571 total time= 4.3min
# [CV 2/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.642 total time= 4.5min
# [CV 3/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.644 total time= 4.6min
# [CV 5/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.652 total time= 4.6min
# [CV 4/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.634 total time= 4.6min
# [CV 1/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.637 total time= 4.6min
# [CV 5/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.684 total time= 5.1min
# [CV 4/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.665 total time= 5.2min
# [CV 2/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.674 total time= 5.2min
# [CV 3/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.676 total time= 5.2min
# [CV 1/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.669 total time= 5.4min
# [CV 2/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.637 total time= 5.5min
# [CV 4/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.631 total time= 5.5min
# [CV 3/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.638 total time= 5.5min
# [CV 5/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.646 total time= 5.6min
# [CV 1/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.629 total time= 5.7min
# [CV 3/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.701 total time= 5.8min
# [CV 4/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.690 total time= 5.8min
# [CV 1/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.695 total time= 5.8min
# [CV 5/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.709 total time= 5.9min
# [CV 2/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.700 total time= 5.9min
# [CV 5/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.687 total time= 6.6min
# [CV 3/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.678 total time= 6.7min
# [CV 1/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.669 total time= 6.7min
# [CV 2/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.678 total time= 6.7min
# [CV 4/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.669 total time= 6.9min
# [CV 5/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.715 total time= 7.6min
# [CV 2/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.707 total time= 7.6min
# [CV 4/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.697 total time= 7.7min
# [CV 3/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.707 total time= 7.7min
# [CV 1/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.699 total time= 7.8min
# [CV 3/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.729 total time= 8.5min
# [CV 2/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.729 total time= 8.5min
# [CV 5/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.736 total time= 8.5min
# [CV 4/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.718 total time= 8.6min
# [CV 1/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.721 total time= 8.7min
#
# ==================================================
# Processing fold 2
# ==================================================
#
# Loading train data for fold 2 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_train_level1_stacked_outer/features_train_level1_outer_g_matched_fold_2.csv
# Columns: ['eid', 'g_pred_train_immune', 'g_pred_train_renalhepatic', 'g_pred_train_metabolic', 'g_pred_train_cardiopulmonary', 'g_pred_train_musculoskeletal', 'g_pred_train_bone_densitometry', 'g_pred_train_pwa', 'g_pred_train_heart_mri', 'g_pred_train_carotid_ultrasound', 'g_pred_train_arterial_stiffness', 'g_pred_train_ecg_rest', 'g_pred_train_body_composition_by_impedance', 'g_pred_train_body_composition_dxa', 'g_pred_train_bone_dxa', 'g_pred_train_kidneys_mri', 'g_pred_train_liver_mri', 'g_pred_train_abdominal_composition_mri_18_vars', 'g_pred_train_abdominal_organ_composition_mri_13_vars', 'g_pred_train_hearing', 'g_pred_train_struct_fast', 'g_pred_train_struct_sub_first', 'g_pred_train_struct_fs_aseg_mean_intensity', 'g_pred_train_struct_fs_aseg_volume', 'g_pred_train_struct_ba_exvivo_area', 'g_pred_train_struct_ba_exvivo_mean_thickness', 'g_pred_train_struct_ba_exvivo_volume', 'g_pred_train_struct_a2009s_area', 'g_pred_train_struct_a2009s_mean_thickness', 'g_pred_train_struct_a2009s_volume', 'g_pred_train_struct_dkt_area', 'g_pred_train_struct_dkt_mean_thickness', 'g_pred_train_struct_dkt_volume', 'g_pred_train_struct_desikan_gw', 'g_pred_train_struct_desikan_pial', 'g_pred_train_struct_desikan_white_area', 'g_pred_train_struct_desikan_white_mean_thickness', 'g_pred_train_struct_desikan_white_volume', 'g_pred_train_struct_subsegmentation', 'g_pred_train_add_t1', 'g_pred_train_add_t2', 'g_pred_train_dwi_FA_tbss', 'g_pred_train_dwi_FA_prob', 'g_pred_train_dwi_MD_tbss', 'g_pred_train_dwi_MD_prob', 'g_pred_train_dwi_L1_tbss', 'g_pred_train_dwi_L1_prob', 'g_pred_train_dwi_L2_tbss', 'g_pred_train_dwi_L2_prob', 'g_pred_train_dwi_L3_tbss', 'g_pred_train_dwi_L3_prob', 'g_pred_train_dwi_MO_tbss', 'g_pred_train_dwi_MO_prob', 'g_pred_train_dwi_OD_tbss', 'g_pred_train_dwi_OD_prob', 'g_pred_train_dwi_ICVF_tbss', 'g_pred_train_dwi_ICVF_prob', 'g_pred_train_dwi_ISOVF_tbss', 'g_pred_train_dwi_ISOVF_prob', 'g_pred_train_aparc_Tian_S1_FA_i2', 'g_pred_train_aparc_Tian_S1_Length_i2', 'g_pred_train_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_train_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_train_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S1_FA_i2', 'g_pred_train_Glasser_Tian_S1_Length_i2', 'g_pred_train_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S4_FA_i2', 'g_pred_train_Glasser_Tian_S4_Length_i2', 'g_pred_train_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_train_amplitudes_21', 'g_pred_train_full_correlation_21', 'g_pred_train_partial_correlation_21', 'g_pred_train_amplitudes_55', 'g_pred_train_full_correlation_55', 'g_pred_train_partial_correlation_55', 'g_pred_train_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_full_correlation_aparc_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S4', 'g_pred_train_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_train_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_partial_correlation_aparc_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S4', 'g_pred_train_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (25518, 102)
#
# Loading test data for fold 2 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_test_level1_stacked_outer/features_test_level1_outer_g_matched_fold_2.csv
# Columns: ['eid', 'g_pred_test_immune', 'g_pred_test_renalhepatic', 'g_pred_test_metabolic', 'g_pred_test_cardiopulmonary', 'g_pred_test_musculoskeletal', 'g_pred_test_bone_densitometry', 'g_pred_test_pwa', 'g_pred_test_heart_mri', 'g_pred_test_carotid_ultrasound', 'g_pred_test_arterial_stiffness', 'g_pred_test_ecg_rest', 'g_pred_test_body_composition_by_impedance', 'g_pred_test_body_composition_dxa', 'g_pred_test_bone_dxa', 'g_pred_test_kidneys_mri', 'g_pred_test_liver_mri', 'g_pred_test_abdominal_composition_mri_18_vars', 'g_pred_test_abdominal_organ_composition_mri_13_vars', 'g_pred_test_hearing', 'g_pred_test_struct_fast', 'g_pred_test_struct_sub_first', 'g_pred_test_struct_fs_aseg_mean_intensity', 'g_pred_test_struct_fs_aseg_volume', 'g_pred_test_struct_ba_exvivo_area', 'g_pred_test_struct_ba_exvivo_mean_thickness', 'g_pred_test_struct_ba_exvivo_volume', 'g_pred_test_struct_a2009s_area', 'g_pred_test_struct_a2009s_mean_thickness', 'g_pred_test_struct_a2009s_volume', 'g_pred_test_struct_dkt_area', 'g_pred_test_struct_dkt_mean_thickness', 'g_pred_test_struct_dkt_volume', 'g_pred_test_struct_desikan_gw', 'g_pred_test_struct_desikan_pial', 'g_pred_test_struct_desikan_white_area', 'g_pred_test_struct_desikan_white_mean_thickness', 'g_pred_test_struct_desikan_white_volume', 'g_pred_test_struct_subsegmentation', 'g_pred_test_add_t1', 'g_pred_test_add_t2', 'g_pred_test_dwi_FA_tbss', 'g_pred_test_dwi_FA_prob', 'g_pred_test_dwi_MD_tbss', 'g_pred_test_dwi_MD_prob', 'g_pred_test_dwi_L1_tbss', 'g_pred_test_dwi_L1_prob', 'g_pred_test_dwi_L2_tbss', 'g_pred_test_dwi_L2_prob', 'g_pred_test_dwi_L3_tbss', 'g_pred_test_dwi_L3_prob', 'g_pred_test_dwi_MO_tbss', 'g_pred_test_dwi_MO_prob', 'g_pred_test_dwi_OD_tbss', 'g_pred_test_dwi_OD_prob', 'g_pred_test_dwi_ICVF_tbss', 'g_pred_test_dwi_ICVF_prob', 'g_pred_test_dwi_ISOVF_tbss', 'g_pred_test_dwi_ISOVF_prob', 'g_pred_test_aparc_Tian_S1_FA_i2', 'g_pred_test_aparc_Tian_S1_Length_i2', 'g_pred_test_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_test_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_test_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S1_FA_i2', 'g_pred_test_Glasser_Tian_S1_Length_i2', 'g_pred_test_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S4_FA_i2', 'g_pred_test_Glasser_Tian_S4_Length_i2', 'g_pred_test_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_test_amplitudes_21', 'g_pred_test_full_correlation_21', 'g_pred_test_partial_correlation_21', 'g_pred_test_amplitudes_55', 'g_pred_test_full_correlation_55', 'g_pred_test_partial_correlation_55', 'g_pred_test_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_full_correlation_aparc_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S4', 'g_pred_test_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_test_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_partial_correlation_aparc_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S4', 'g_pred_test_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (6379, 102)
# Started RF
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 5/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.321 total time= 1.5min
# [CV 2/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.318 total time= 1.6min
# [CV 1/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.326 total time= 1.6min
# [CV 3/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.309 total time= 1.6min
# [CV 4/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.313 total time= 1.6min
# [CV 1/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.358 total time= 2.4min
# [CV 4/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.344 total time= 2.4min
# [CV 2/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.352 total time= 2.4min
# [CV 5/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.354 total time= 2.4min
# [CV 3/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.340 total time= 2.5min
# [CV 3/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.485 total time= 2.7min
# [CV 1/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.492 total time= 2.7min
# [CV 2/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.492 total time= 2.7min
# [CV 5/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.493 total time= 2.8min
# [CV 4/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.484 total time= 2.8min
# [CV 2/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.565 total time= 3.7min
# [CV 1/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.561 total time= 3.7min
# [CV 4/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.552 total time= 3.7min
# [CV 3/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.557 total time= 3.7min
# [CV 5/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.563 total time= 3.8min
# [CV 3/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.525 total time= 4.1min
# [CV 1/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.531 total time= 4.2min
# [CV 2/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.533 total time= 4.3min
# [CV 4/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.523 total time= 4.3min
# [CV 5/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.532 total time= 4.3min
# [CV 3/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.603 total time= 4.5min
# [CV 5/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.607 total time= 4.5min
# [CV 4/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.595 total time= 4.6min
# [CV 2/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.611 total time= 4.6min
# [CV 1/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.605 total time= 4.6min
# [CV 4/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.625 total time= 5.2min
# [CV 5/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.637 total time= 5.2min
# [CV 3/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.635 total time= 5.2min
# [CV 2/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.642 total time= 5.3min
# [CV 1/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.636 total time= 5.3min
# [CV 2/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.600 total time= 5.6min
# [CV 5/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.597 total time= 5.6min
# [CV 3/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.592 total time= 5.6min
# [CV 4/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.585 total time= 5.6min
# [CV 1/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.593 total time= 5.6min
# [CV 4/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.649 total time= 5.7min
# [CV 2/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.667 total time= 5.8min
# [CV 1/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.660 total time= 5.8min
# [CV 5/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.661 total time= 5.9min
# [CV 3/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.660 total time= 5.9min
# [CV 2/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.641 total time= 6.7min
# [CV 1/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.632 total time= 6.7min
# [CV 5/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.636 total time= 6.7min
# [CV 4/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.623 total time= 6.7min
# [CV 3/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.633 total time= 6.8min
# [CV 2/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.671 total time= 7.6min
# [CV 4/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.651 total time= 7.6min
# [CV 5/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.664 total time= 7.7min
# [CV 1/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.661 total time= 7.7min
# [CV 3/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.663 total time= 7.9min
# [CV 3/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.685 total time= 8.6min
# [CV 1/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.683 total time= 8.6min
# [CV 2/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.692 total time= 8.6min
# [CV 4/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.672 total time= 8.6min
# [CV 5/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.684 total time= 8.7min
#
# ==================================================
# Processing fold 3
# ==================================================
#
# Loading train data for fold 3 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_train_level1_stacked_outer/features_train_level1_outer_g_matched_fold_3.csv
# Columns: ['eid', 'g_pred_train_immune', 'g_pred_train_renalhepatic', 'g_pred_train_metabolic', 'g_pred_train_cardiopulmonary', 'g_pred_train_musculoskeletal', 'g_pred_train_bone_densitometry', 'g_pred_train_pwa', 'g_pred_train_heart_mri', 'g_pred_train_carotid_ultrasound', 'g_pred_train_arterial_stiffness', 'g_pred_train_ecg_rest', 'g_pred_train_body_composition_by_impedance', 'g_pred_train_body_composition_dxa', 'g_pred_train_bone_dxa', 'g_pred_train_kidneys_mri', 'g_pred_train_liver_mri', 'g_pred_train_abdominal_composition_mri_18_vars', 'g_pred_train_abdominal_organ_composition_mri_13_vars', 'g_pred_train_hearing', 'g_pred_train_struct_fast', 'g_pred_train_struct_sub_first', 'g_pred_train_struct_fs_aseg_mean_intensity', 'g_pred_train_struct_fs_aseg_volume', 'g_pred_train_struct_ba_exvivo_area', 'g_pred_train_struct_ba_exvivo_mean_thickness', 'g_pred_train_struct_ba_exvivo_volume', 'g_pred_train_struct_a2009s_area', 'g_pred_train_struct_a2009s_mean_thickness', 'g_pred_train_struct_a2009s_volume', 'g_pred_train_struct_dkt_area', 'g_pred_train_struct_dkt_mean_thickness', 'g_pred_train_struct_dkt_volume', 'g_pred_train_struct_desikan_gw', 'g_pred_train_struct_desikan_pial', 'g_pred_train_struct_desikan_white_area', 'g_pred_train_struct_desikan_white_mean_thickness', 'g_pred_train_struct_desikan_white_volume', 'g_pred_train_struct_subsegmentation', 'g_pred_train_add_t1', 'g_pred_train_add_t2', 'g_pred_train_dwi_FA_tbss', 'g_pred_train_dwi_FA_prob', 'g_pred_train_dwi_MD_tbss', 'g_pred_train_dwi_MD_prob', 'g_pred_train_dwi_L1_tbss', 'g_pred_train_dwi_L1_prob', 'g_pred_train_dwi_L2_tbss', 'g_pred_train_dwi_L2_prob', 'g_pred_train_dwi_L3_tbss', 'g_pred_train_dwi_L3_prob', 'g_pred_train_dwi_MO_tbss', 'g_pred_train_dwi_MO_prob', 'g_pred_train_dwi_OD_tbss', 'g_pred_train_dwi_OD_prob', 'g_pred_train_dwi_ICVF_tbss', 'g_pred_train_dwi_ICVF_prob', 'g_pred_train_dwi_ISOVF_tbss', 'g_pred_train_dwi_ISOVF_prob', 'g_pred_train_aparc_Tian_S1_FA_i2', 'g_pred_train_aparc_Tian_S1_Length_i2', 'g_pred_train_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_train_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_train_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S1_FA_i2', 'g_pred_train_Glasser_Tian_S1_Length_i2', 'g_pred_train_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S4_FA_i2', 'g_pred_train_Glasser_Tian_S4_Length_i2', 'g_pred_train_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_train_amplitudes_21', 'g_pred_train_full_correlation_21', 'g_pred_train_partial_correlation_21', 'g_pred_train_amplitudes_55', 'g_pred_train_full_correlation_55', 'g_pred_train_partial_correlation_55', 'g_pred_train_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_full_correlation_aparc_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S4', 'g_pred_train_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_train_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_partial_correlation_aparc_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S4', 'g_pred_train_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (25518, 102)
#
# Loading test data for fold 3 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_test_level1_stacked_outer/features_test_level1_outer_g_matched_fold_3.csv
# ...
# [CV 5/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.661 total time= 5.7min
# [CV 3/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.658 total time= 5.7min
# [CV 4/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.655 total time= 5.7min
# [CV 1/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.666 total time= 5.7min
# [CV 5/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.635 total time= 6.4min
# [CV 2/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.637 total time= 6.5min
# [CV 3/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.632 total time= 6.5min
# [CV 4/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.628 total time= 6.6min
# [CV 1/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.636 total time= 6.6min
# [CV 5/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.663 total time= 7.4min
# [CV 2/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.666 total time= 7.5min
# [CV 4/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.657 total time= 7.5min
# [CV 3/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.661 total time= 7.5min
# [CV 1/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.666 total time= 7.5min
# [CV 3/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.682 total time= 8.4min
# [CV 5/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.684 total time= 8.4min
# [CV 1/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.688 total time= 8.5min
# [CV 2/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.687 total time= 8.5min
# [CV 4/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.678 total time= 8.5min
#
# ==================================================
# Processing fold 4
# ==================================================
#
# Loading train data for fold 4 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_train_level1_stacked_outer/features_train_level1_outer_g_matched_fold_4.csv
# Columns: ['eid', 'g_pred_train_immune', 'g_pred_train_renalhepatic', 'g_pred_train_metabolic', 'g_pred_train_cardiopulmonary', 'g_pred_train_musculoskeletal', 'g_pred_train_bone_densitometry', 'g_pred_train_pwa', 'g_pred_train_heart_mri', 'g_pred_train_carotid_ultrasound', 'g_pred_train_arterial_stiffness', 'g_pred_train_ecg_rest', 'g_pred_train_body_composition_by_impedance', 'g_pred_train_body_composition_dxa', 'g_pred_train_bone_dxa', 'g_pred_train_kidneys_mri', 'g_pred_train_liver_mri', 'g_pred_train_abdominal_composition_mri_18_vars', 'g_pred_train_abdominal_organ_composition_mri_13_vars', 'g_pred_train_hearing', 'g_pred_train_struct_fast', 'g_pred_train_struct_sub_first', 'g_pred_train_struct_fs_aseg_mean_intensity', 'g_pred_train_struct_fs_aseg_volume', 'g_pred_train_struct_ba_exvivo_area', 'g_pred_train_struct_ba_exvivo_mean_thickness', 'g_pred_train_struct_ba_exvivo_volume', 'g_pred_train_struct_a2009s_area', 'g_pred_train_struct_a2009s_mean_thickness', 'g_pred_train_struct_a2009s_volume', 'g_pred_train_struct_dkt_area', 'g_pred_train_struct_dkt_mean_thickness', 'g_pred_train_struct_dkt_volume', 'g_pred_train_struct_desikan_gw', 'g_pred_train_struct_desikan_pial', 'g_pred_train_struct_desikan_white_area', 'g_pred_train_struct_desikan_white_mean_thickness', 'g_pred_train_struct_desikan_white_volume', 'g_pred_train_struct_subsegmentation', 'g_pred_train_add_t1', 'g_pred_train_add_t2', 'g_pred_train_dwi_FA_tbss', 'g_pred_train_dwi_FA_prob', 'g_pred_train_dwi_MD_tbss', 'g_pred_train_dwi_MD_prob', 'g_pred_train_dwi_L1_tbss', 'g_pred_train_dwi_L1_prob', 'g_pred_train_dwi_L2_tbss', 'g_pred_train_dwi_L2_prob', 'g_pred_train_dwi_L3_tbss', 'g_pred_train_dwi_L3_prob', 'g_pred_train_dwi_MO_tbss', 'g_pred_train_dwi_MO_prob', 'g_pred_train_dwi_OD_tbss', 'g_pred_train_dwi_OD_prob', 'g_pred_train_dwi_ICVF_tbss', 'g_pred_train_dwi_ICVF_prob', 'g_pred_train_dwi_ISOVF_tbss', 'g_pred_train_dwi_ISOVF_prob', 'g_pred_train_aparc_Tian_S1_FA_i2', 'g_pred_train_aparc_Tian_S1_Length_i2', 'g_pred_train_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_train_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_train_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S1_FA_i2', 'g_pred_train_Glasser_Tian_S1_Length_i2', 'g_pred_train_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_train_Glasser_Tian_S4_FA_i2', 'g_pred_train_Glasser_Tian_S4_Length_i2', 'g_pred_train_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_train_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_train_amplitudes_21', 'g_pred_train_full_correlation_21', 'g_pred_train_partial_correlation_21', 'g_pred_train_amplitudes_55', 'g_pred_train_full_correlation_55', 'g_pred_train_partial_correlation_55', 'g_pred_train_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_full_correlation_aparc_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S1', 'g_pred_train_full_correlation_Glasser_Tian_S4', 'g_pred_train_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_train_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_train_partial_correlation_aparc_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S1', 'g_pred_train_partial_correlation_Glasser_Tian_S4', 'g_pred_train_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_train_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (25518, 102)
#
# Loading test data for fold 4 from: /media/hcs-sci-psy-narun/IBu/UK_BB/brainbody/stacking/brain-body/features_test_level1_stacked_outer/features_test_level1_outer_g_matched_fold_4.csv
# Columns: ['eid', 'g_pred_test_immune', 'g_pred_test_renalhepatic', 'g_pred_test_metabolic', 'g_pred_test_cardiopulmonary', 'g_pred_test_musculoskeletal', 'g_pred_test_bone_densitometry', 'g_pred_test_pwa', 'g_pred_test_heart_mri', 'g_pred_test_carotid_ultrasound', 'g_pred_test_arterial_stiffness', 'g_pred_test_ecg_rest', 'g_pred_test_body_composition_by_impedance', 'g_pred_test_body_composition_dxa', 'g_pred_test_bone_dxa', 'g_pred_test_kidneys_mri', 'g_pred_test_liver_mri', 'g_pred_test_abdominal_composition_mri_18_vars', 'g_pred_test_abdominal_organ_composition_mri_13_vars', 'g_pred_test_hearing', 'g_pred_test_struct_fast', 'g_pred_test_struct_sub_first', 'g_pred_test_struct_fs_aseg_mean_intensity', 'g_pred_test_struct_fs_aseg_volume', 'g_pred_test_struct_ba_exvivo_area', 'g_pred_test_struct_ba_exvivo_mean_thickness', 'g_pred_test_struct_ba_exvivo_volume', 'g_pred_test_struct_a2009s_area', 'g_pred_test_struct_a2009s_mean_thickness', 'g_pred_test_struct_a2009s_volume', 'g_pred_test_struct_dkt_area', 'g_pred_test_struct_dkt_mean_thickness', 'g_pred_test_struct_dkt_volume', 'g_pred_test_struct_desikan_gw', 'g_pred_test_struct_desikan_pial', 'g_pred_test_struct_desikan_white_area', 'g_pred_test_struct_desikan_white_mean_thickness', 'g_pred_test_struct_desikan_white_volume', 'g_pred_test_struct_subsegmentation', 'g_pred_test_add_t1', 'g_pred_test_add_t2', 'g_pred_test_dwi_FA_tbss', 'g_pred_test_dwi_FA_prob', 'g_pred_test_dwi_MD_tbss', 'g_pred_test_dwi_MD_prob', 'g_pred_test_dwi_L1_tbss', 'g_pred_test_dwi_L1_prob', 'g_pred_test_dwi_L2_tbss', 'g_pred_test_dwi_L2_prob', 'g_pred_test_dwi_L3_tbss', 'g_pred_test_dwi_L3_prob', 'g_pred_test_dwi_MO_tbss', 'g_pred_test_dwi_MO_prob', 'g_pred_test_dwi_OD_tbss', 'g_pred_test_dwi_OD_prob', 'g_pred_test_dwi_ICVF_tbss', 'g_pred_test_dwi_ICVF_prob', 'g_pred_test_dwi_ISOVF_tbss', 'g_pred_test_dwi_ISOVF_prob', 'g_pred_test_aparc_Tian_S1_FA_i2', 'g_pred_test_aparc_Tian_S1_Length_i2', 'g_pred_test_aparc_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_Tian_S1_Streamline_Count_i2', 'g_pred_test_aparc_a2009s_Tian_S1_FA_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Length_i2', 'g_pred_test_aparc_a2009s_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_aparc_a2009s_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S1_FA_i2', 'g_pred_test_Glasser_Tian_S1_Length_i2', 'g_pred_test_Glasser_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S1_Streamline_Count_i2', 'g_pred_test_Glasser_Tian_S4_FA_i2', 'g_pred_test_Glasser_Tian_S4_Length_i2', 'g_pred_test_Glasser_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Glasser_Tian_S4_Streamline_Count_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_FA_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Length_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n200p_Tian_S1_Streamline_Count_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_FA_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Length_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_SIFT2_FBC_i2', 'g_pred_test_Schaefer7n1000p_Tian_S4_Streamline_Count_i2', 'g_pred_test_amplitudes_21', 'g_pred_test_full_correlation_21', 'g_pred_test_partial_correlation_21', 'g_pred_test_amplitudes_55', 'g_pred_test_full_correlation_55', 'g_pred_test_partial_correlation_55', 'g_pred_test_full_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_full_correlation_aparc_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S1', 'g_pred_test_full_correlation_Glasser_Tian_S4', 'g_pred_test_full_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_full_correlation_Schaefer7n500p_Tian_S4', 'g_pred_test_partial_correlation_aparc_a2009s_Tian_S1', 'g_pred_test_partial_correlation_aparc_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S1', 'g_pred_test_partial_correlation_Glasser_Tian_S4', 'g_pred_test_partial_correlation_Schaefer7n200p_Tian_S1', 'g_pred_test_partial_correlation_Schaefer7n500p_Tian_S4', 'g']
# Shape: (6379, 102)
# Started RF
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 2/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.320 total time= 1.5min
# [CV 5/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.321 total time= 1.5min
# [CV 3/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.312 total time= 1.5min
# [CV 4/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.322 total time= 1.5min
# [CV 1/5] END max_depth=1, max_features=log2, n_estimators=5000;, score=0.326 total time= 1.5min
# [CV 1/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.353 total time= 2.4min
# [CV 4/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.348 total time= 2.4min
# [CV 2/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.345 total time= 2.4min
# [CV 5/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.347 total time= 2.4min
# [CV 3/5] END max_depth=1, max_features=sqrt, n_estimators=5000;, score=0.337 total time= 2.4min
# [CV 2/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.490 total time= 2.6min
# [CV 3/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.485 total time= 2.7min
# [CV 1/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.490 total time= 2.7min
# [CV 5/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.490 total time= 2.7min
# [CV 4/5] END max_depth=2, max_features=log2, n_estimators=5000;, score=0.492 total time= 2.7min
# [CV 2/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.558 total time= 3.6min
# [CV 4/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.558 total time= 3.6min
# [CV 3/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.552 total time= 3.6min
# [CV 5/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.558 total time= 3.7min
# [CV 1/5] END max_depth=3, max_features=log2, n_estimators=5000;, score=0.556 total time= 3.7min
# [CV 4/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.522 total time= 4.1min
# [CV 3/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.515 total time= 4.1min
# [CV 1/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.520 total time= 4.1min
# [CV 2/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.519 total time= 4.1min
# [CV 5/5] END max_depth=2, max_features=sqrt, n_estimators=5000;, score=0.521 total time= 4.1min
# [CV 1/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.597 total time= 4.4min
# [CV 4/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.599 total time= 4.4min
# [CV 3/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.593 total time= 4.4min
# [CV 2/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.600 total time= 4.4min
# [CV 5/5] END max_depth=4, max_features=log2, n_estimators=5000;, score=0.600 total time= 4.4min
# [CV 2/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.630 total time= 5.1min
# [CV 3/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.622 total time= 5.1min
# [CV 5/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.629 total time= 5.1min
# [CV 1/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.627 total time= 5.1min
# [CV 4/5] END max_depth=5, max_features=log2, n_estimators=5000;, score=0.627 total time= 5.1min
# [CV 3/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.577 total time= 5.4min
# [CV 1/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.579 total time= 5.5min
# [CV 4/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.582 total time= 5.5min
# [CV 5/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.583 total time= 5.5min
# [CV 2/5] END max_depth=3, max_features=sqrt, n_estimators=5000;, score=0.582 total time= 5.5min
# [CV 2/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.655 total time= 5.7min
# [CV 5/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.653 total time= 5.7min
# [CV 1/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.651 total time= 5.7min
# [CV 4/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.650 total time= 5.7min
# [CV 3/5] END max_depth=6, max_features=log2, n_estimators=5000;, score=0.646 total time= 5.7min
# [CV 1/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.617 total time= 6.4min
# [CV 2/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.621 total time= 6.5min
# [CV 5/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.622 total time= 6.5min
# [CV 4/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.619 total time= 6.5min
# [CV 3/5] END max_depth=4, max_features=sqrt, n_estimators=5000;, score=0.614 total time= 6.5min
# [CV 4/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.646 total time= 7.4min
# [CV 3/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.642 total time= 7.5min
# [CV 2/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.650 total time= 7.5min
# [CV 1/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.646 total time= 7.5min
# [CV 5/5] END max_depth=5, max_features=sqrt, n_estimators=5000;, score=0.650 total time= 7.6min
# [CV 1/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.668 total time= 8.4min
# [CV 5/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.671 total time= 8.4min
# [CV 3/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.664 total time= 8.4min
# [CV 4/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.667 total time= 8.4min
# [CV 2/5] END max_depth=6, max_features=sqrt, n_estimators=5000;, score=0.672 total time= 8.5min
#
# All folds processed successfully!
